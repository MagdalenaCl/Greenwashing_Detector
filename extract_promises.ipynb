# %%
import fitz  # PyMuPDF

def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text()
    return text

def clean_text(text):
    import re
    text = text.replace("\n", " ")
    text = re.sub(r'\s+', ' ', text)  # Mehrfache Leerzeichen entfernen
    return text.strip()

def chunk_text(text, max_length=500):
    import re
    sentences = re.split(r'(?<=[.!?])\s+', text)
    chunks, current_chunk = [], ""
    
    for sentence in sentences:
        if len(current_chunk) + len(sentence) <= max_length:
            current_chunk += " " + sentence
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence
    if current_chunk:
        chunks.append(current_chunk.strip())
    
    return chunks

raw_text = extract_text_from_pdf("2023_Volkswagen_Group_Nachhaltigkeitsbericht.pdf")
text = clean_text(raw_text)
chunks = chunk_text(text)

# %% [markdown]
# # Text in cunks unterteilen

# %%
print(chunks)
# Out:
# ['', '2023 N A C H H A LT I G K E I T S B E R I C H T Inhalt Navigationshilfe Kapitelverweise innerhalb des Nachhaltigkeitsberichts Verweise auf Websites 6 Vorwort 9 Über den Bericht 12 \x07 Nachhaltigkeit in der Unternehmens-DNA 13 Corporate Governance 17 Konzernstrategie NEW AUTO 22 \x07ESG-Performance-Management und Wesentlichkeitsanalyse 25 Nachhaltigkeitsmanagement 27 \x07Nachhaltigkeitswirkungen neuer Mobilitätsangebote 30 Stakeholder-Management 33 Umwelt-Compliance-Management 42 Risikomanagement 45 Corporate Citizenship Fokusthemen 1 \x07Dekarbonisierung 48 Dekarbonisierung 69 EU-Taxonomie 2 \x07Kreislaufwirtschaft 83 Kreislaufwirtschaft 3 \x07Menschen in der Transformation 90 Menschen in der Transformation 4 \x07Vielfalt 104 Vielfalt 5 \x07Integrität und Compliance 109 Integrität und Compliance 6 \x07Lieferkette und Menschenrechte 117 Lieferkette und Menschenrechte 131 Anhang 132 \x07Vermerk des unabhängigen Wirtschaftsprüfers 135 Impressum 2 Nachhaltigkeits\xad kommunikation des Volkswagen Konzerns 2023 G E S C H Ä F T S B E R I C H T 2023 N A C H H A LT I G K E I T S B E R I C H T \x07Begleitende Informationen zur Berichterstattung ESG-Kennzahlen Indikatoren entlang unserer Fokusthemen sind in Excel übersichtlich dargestellt GRI-Index GRI-Inhaltsindex (unter Bezugnahme) SASB-Index Index Automobile Berichte zu Sonderthemen Responsible Raw Materials Report Fortschritte bei Transparenz und Risiko\xad minderung in den Rohstofflieferketten (jährlich) Association Climate Review Report Übersicht zu klimapolitischen Positionen Green Finance Report Umsetzung nachhaltiger Finanzierungs\xad strategien (jährlich) Weitere ESG-Themen Informationen zu weiteren Themen, die im Be\xad reich Nachhaltigkeit und ESG von Bedeutung sind \x07Informationen auf der Konzern-Website Policies Selbstverpflichtungen und Grundsätze, die konzernweit gelten ESG-Kontroversen Informationen zu aktuellen und laufenden \xadKontroversen in sachlicher Form Internationale Initiativen UN Sustainable Development Goals Aktivitäten und Projekte, die zur Erreichung der Nachhaltigkeitsziele beitragen (jährlich) UN Global Compact Umsetzung der zehn UN-Global-Compact- Prinzipien (jährlich) CDP Score Report – Climate Change Bewertung der klimabezogenen Risiken, Ziele und Maßnahmen CDP Score Report – Water Security Bewertung im Bereich Wasserressourcen Nachhaltigkeit und ESG sind Teil der Konzernstrategie ESG-Performance ESG-Performance Ziel ist es, die Leistung in ESG-Ratings und -Rankings des Kapitalmarkts zu ver\xad bessern, um die Investitionsfähigkeit zu steigern und Kapitalkosten zu optimieren.', 'Auf unserem Weg vom Automobilhersteller zum Mobilitätskonzern ordnen wir mit der Konzernstrategie NEW AUTO unsere Prioritäten neu und stellen uns zukunftsgerichtet auf. Dabei behalten wir unser Ziel, ein weltweit führender Anbieter nachhaltiger Mobilität zu sein, fest im Blick und richten den Konzern fokussierter, effizienter, innovativer, kundennäher, nachhaltiger und konsequent auf profitables Wachstum aus.', 'Die Konzernstrategie NEW AUTO definiert für den Bereich Nachhaltigkeit und ESG in der Konzerninitiative 6 die sechs oben ab\xadgebil\xaddeten wesentlichen Fokusthemen. Nach diesen ist der vorliegende Nachhaltigkeitsbericht inklusive nichtfinanzieller Bericht strukturiert.', 'Darüber hinaus erfolgt im Kapitel „Nachhaltigkeit in der Unternehmens-DNA“ eine Definition von Nachhaltigkeit für das Unternehmen und ein Einblick in Themen wie Risikomanagement, Umweltmanagement, Stakeholder-Management und Corporate Citizenship.', '\x07Nachhaltigkeit in der Unter\xad nehmens-\xadDNA \x07Dekarbonisierung \x07Kreislauf\xad wirtschaft \x07Menschen in der Transformation Vielfalt \x07Integrität und Compliance \x07Lieferkette und Menschenrechte Progressive Core Sport Luxury Trucks Architecture Software Battery, Charging & Energy Volkswagen Group Mobility 06 | ESG, Decarbonization and Integrity Highlights 20231 \x07Dekarbonisierung Zugang zu 600.000 Ladepunkten in Europa Bis 2030 ...

# %% [markdown]
# # KeyBERT zur Extraktion der relevantesten Aussagen

# %%
from keybert import KeyBERT
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("paraphrase-MiniLM-L6-v2")
kw_model = KeyBERT(model=model)

keywords_per_chunk = [
    (chunk, kw_model.extract_keywords(chunk, keyphrase_ngram_range=(1, 3), stop_words='german', top_n=3))
    for chunk in chunks
]

# %%
for i, p in enumerate(keywords_per_chunk, 1):
    print(f"{i}. {p}\n")
# Out:
# 1. ('', [])
#
# 2. ('2023 N A C H H A LT I G K E I T S B E R I C H T Inhalt Navigationshilfe Kapitelverweise innerhalb des Nachhaltigkeitsberichts Verweise auf Websites 6 Vorwort 9 Über den Bericht 12 \x07 Nachhaltigkeit in der Unternehmens-DNA 13 Corporate Governance 17 Konzernstrategie NEW AUTO 22 \x07ESG-Performance-Management und Wesentlichkeitsanalyse 25 Nachhaltigkeitsmanagement 27 \x07Nachhaltigkeitswirkungen neuer Mobilitätsangebote 30 Stakeholder-Management 33 Umwelt-Compliance-Management 42 Risikomanagement 45 Corporate Citizenship Fokusthemen 1 \x07Dekarbonisierung 48 Dekarbonisierung 69 EU-Taxonomie 2 \x07Kreislaufwirtschaft 83 Kreislaufwirtschaft 3 \x07Menschen in der Transformation 90 Menschen in der Transformation 4 \x07Vielfalt 104 Vielfalt 5 \x07Integrität und Compliance 109 Integrität und Compliance 6 \x07Lieferkette und Menschenrechte 117 Lieferkette und Menschenrech
# 41. ('€ im Anhang angegeben, auf die Anlegerverfahren in Deutschland entfallen davon rund 3,8 (3,6) Mrd. €. Aufgrund der noch nicht abgeschlossenen Sachverhaltsaufklärung sowie der Vielschichtigkeit der einzelnen Einflussfaktoren und der noch andauernden Ab\xad stimmungen mit den Behörden unterliegen die im Zusam\xad menhang mit der Dieselthematik gebildeten Rückstellungen sowie die angegebenen Eventualverbindlichkeiten und die weiteren latenten Rechtsrisiken zum Teil erheblichen Ein\xad schätzungsrisiken.', [])
#
# 42. ('Sollten sich diese Rechts- beziehungsweise Einschätzungsrisiken verwirklichen, kann dies zu weiteren erheblichen finanziellen Belastungen führen. Insbesondere Als Mitglied des Global Compact der Vereinten Nationen (UN Global Compact) berichten wir außerdem kontinuierlich, wie wir die zehn Prinzipien in die Unternehmenspraxis um\xad setzen.', [])
#
# 43. ('Unser aktueller Fortschrittsbericht ist auf der Web- site des UN Global Compact einsehbar: United Nations Global Compact Das Strategiekapitel und die sechs folgenden Fokuskapitel des Berichts bestehen je aus einem Textteil sowie einer konsoli\xad dierten Kennzahlentabelle, die am Ende jedes Kapitels steht. Verweise auf Angaben außerhalb des nichtfinanziellen Be\xad richts sind weiterführende Informationen und nicht Bestand\xad teil dieses Berichts.', [])
#
# 44. ('Ebenso sind folgende Passagen nicht Bestandteil des nichtfinanziellen Berichts: • Nachhaltigkeitskommunikation des Volkswagen \xadKonzerns (S. 3–4) • Vorwort (S. 6–8) • Der Deutsche Corporate Governance Kodex – Leitlinie für erfolgreiche Unternehmensführung (S. 15) • Weiterführende Informationen und Wertschöpfungskette (S. 16) • Soziale und ökologische Auswirkungen unseres Handelns messbar machen (S. 24) Die Angaben in diesem Bericht beziehen sich auf den ge\xad samten Volkswagen Konzern.', [])
#
# 45. ('Sofern Informationen nur ein\xad zelne Konzernbereiche betreffen, wird dies im Text kenntlich gemacht. Grundsätzlich gelten alle Angaben über den Konzern auch für die Volkswagen AG, bei Abweichung wird dies ausdrücklich genannt. In den Konzern werden neben der Volkswagen AG alle wesentlichen in- und ausländischen Tochterunternehmen einbezogen, die die Volkswagen AG unmittelbar oder mittelbar beherrscht.', [])
#
# 46. ('Unsere Joint Ventures in China werden in die Finanzdaten nach der At-Equity-Methode einbezogen und sind in den Mengen\xad daten (Absatz, Produktion und Belegschaft) sowie in den produktionsbezogenen Umweltdaten zu 100 % enthalten. Die in diesem Bericht beschriebenen Managementansätze (wie beispielsweise das Umwelt-Compliance-Managementsystem) gelten für alle kontrollierten Gesellschaften des Volkswagen Konzerns.', [])
#
# 47. ('Bei unseren nicht kontrollierten Gesellschaften, also Unternehmen, die nicht durch ein Unternehmen des Volkswagen Konzerns kontrolliert werden, wirken wir im Rahmen des faktisch Möglichen und rechtlich Zulässigen da\xad rauf hin, dass angepasste Managementansätze umgesetzt werden.', [])
#
# 48. ('In den Kennzahlen und in den dazugehörigen Zielen bei den Themen Umweltentlastung Produktion (UEP), Dekarbo\xad nisierungsindex (DKI), Stimmungsbarometer, Diversity-Index, GRI 2-2, 2-4, 2-5 Inhalt\x08 Unternehmens-DNA | Dekarbonisierung | Kreislaufwirtschaft | Menschen in der Transformation | Vielfalt | Integrität und Compliance | Lieferkette und Menschenrechte 11 lässt sich nicht ausschließen, dass aufgrund von zukünftigen Erkenntnissen oder Ereignissen die gebildeten Rückstellungen möglicherweise angepasst werden müssen.', [])
#
# 49. ('Die übrigen Rückstellungen betreffen eine Vielzahl erkenn\xad barer Einzelrisiken, Preisrisiken und ungewisser Verpflich\xad tungen, die in Höhe ihres wahrscheinlichen Eintritts berück\xad sichtigt werden. Abhängig von der jeweiligen Jurisdiktion sind darin auch Risikovorsorgen für die etwaige Nichteinhaltung von gesetzlichen Emissionsobergrenzen enthalten.', [])
#
# 50. ('Deren Bewertung erfolgte unter anderem unter Berücksichtigung des jeweiligen Absatzvolumens und der gesetzlich definierten Abgabe beziehungsweise der Kosten für den Erwerb von Emissionsrechten anderer Hersteller. Die Synergien der ein\xad zelnen Marken des Volkswagen Konzerns wurden dabei nach Möglichkeit in Form von Emissionsgemeinschaften genutzt.', [])
#
# 51. ('Zusätzliche Erläuterungen zu diesem Sachverhalt und den Bewertungsannahmen und -grundlagen finden sich im Ge\xad schäftsbericht im Anhang zum Konzernabschluss.', [])
#
# 52. ('Weitere Berichterstattung im Konzern Alle infolge der Richtlinie 2014/95/EU zur Offenlegung von nichtfinanziellen und die Diversität betreffenden Informationen auf Basis nationaler Gesetzgebung verpflichteten Konzern\xad gesellschaften, die keine eigene nichtfinanzielle Erklärung abgeben, befreien sich durch den Verweis auf diesen zusam\xad mengefassten gesonderten nichtfinanziellen Bericht von der Pflicht, einen eigenen nichtfinanziellen Bericht abzugeben.', [])
#
# 53. ('Klimaschutzbezogene Begrifflichkeiten Die Verwendung des Begriffs CO2-Emissionen in diesem Be\xad richt schließt die Betrachtung und Ermittlung weiterer klima\xad schädlicher Treibhausgase wie zum Beispiel Methan (CH₄) und Lachgas (N₂O) mit ein (CO2-Äquivalente). Alle Angaben in diesem Bericht zu CO2-Emissionen entsprechen CO2-Äqui\xad valenten. Dies gilt nicht für die Werte der Flottenemissionen.', [])
#
# 54. ('Bilanzielle CO2-Neutralität wird erreicht, wenn anthropogene CO2-Emissionen weltweit durch die Vermeidung, Reduktion und Kompensation über einen spezifischen Zeitraum ausge\xad glichen werden. Beim Klimaschutz achtet Volkswagen neben CO2-Emissionen auch auf alle anderen relevanten Treibhaus\xad gase. Für den Volkswagen Konzern haben Vermeidung und Reduktion Priorität gegenüber Kompensation. Für Maßnahmen der Kompensation folgt das Unternehmen international etablierten Standards.', [])
#
# 55. ('Redaktionelle Hinweise Aufgrund der besseren Lesbarkeit sprechen wir im nichtfinan\xad ziellen Bericht durchgängig von Mitarbeitern. Damit sind selbstverständlich alle Geschlechter gleichermaßen ange\xad sprochen. Gleiches gilt auch für ähnliche Begriffe wie Teil\xad nehmer, Vertreter, Lieferant etc. Ist im vorliegenden Bericht von Nachhaltigkeitsbericht die Rede, so schließt dieser Ausdruck bei jeder Nennung den nichtfinan\xad ziellen Bericht in dem auf S. 10 beschriebenen Umfang mit ein.', [])
#
# 56. ('Berichtspraxis Der nichtfinanzielle Bericht erscheint jährlich. Der letzte nichtfinanzielle Bericht wurde am 12. März 2023 veröffent\xad licht. Der vorliegende nichtfinanzielle Bericht 2023 enthält neben den Nachhaltigkeitsaktivitäten des Konzerns im Ge\xad schäftsjahr 2023 (1. Januar bis 31. Dezember 2023) auch ausgewählte Informationen aus dem Geschäftsjahr 2024. Über den Bericht Redaktionsschluss dieses Berichts war der 14. Februar 2024.', [])
# 71. ('Im Bereich Power Engineering wird das Geschäft mit Groß\xad dieselmotoren, Turbomaschinen und Komponenten der An\xad triebstechnik abgebildet. Die Tätigkeit des Konzernbereichs Finanzdienstleistungen umfasst die Händler- und Kunden\xad finanzierung, das Leasing, das Direktbank- und Versiche\xad rungsgeschäft sowie das Flottenmanagement und Mobilitäts\xad angebote. Mit seinen Marken ist der Volkswagen Konzern auf allen für ihn relevanten Märkten der Welt vertreten.', [])
#
# 72. ('Zu den wesentlichen Märkten gehören derzeit die Region Westeuropa sowie die Länder China, USA, Brasilien, Türkei, Mexiko, Polen und Tschechien. Die Volkswagen AG und der Volkswagen Konzern werden vom Vorstand der Volkswagen AG auf Grundlage der Satzung der Volkswagen AG und der durch den Aufsichtsrat erlassenen Ge\xad schäftsordnung für den Vorstand der Volkswagen AG geleitet. Danach sind die Aufgaben im Vorstand derzeit auf zehn Ge\xad schäftsbereiche aufgeteilt.', [])
#
# 73. ('Neben dem Geschäfts\xadbereich „Vorsitzender des Vorstands“ sind das „Technik“, „Finanz und Operative Steuerung“ (vormals „Finanzen“), „Personal und Markengruppe Trucks“ (vormals „Personal und Truck & Bus“), „Integrität und Recht“, „Markengruppe Progressive“ (vormals „Premium“), „Markengruppe Sport Luxury“ (vormals „Sport & Luxury“), „IT“, „China“ sowie Markengruppe Core (vormals \xad„Volumen“).', [])
#
# 74. ('Dabei wird der Geschäftsbereich „Markengruppe Sport Luxury“ vom Vorsitzenden des Vorstands in Personal\xad union geführt. Den Geschäftsbereichen schließt sich direkt die erweiterte Konzernleitung an, die die Funktionen „Konzern Vertrieb“, „Konzern Produktion“, „Konzern Beschaffung“ und „Konzern Forschung und Entwicklung“ umfasst. Die Aufgabenverteilung des Vorstands beruht auf der vom Auf\xad sichtsrat beschlossenen Geschäftsordnung.', [])
#
# 75. ('Ihre Struktur trägt dazu bei, dass wesentliche Aufgaben wie Strategie, zentrale Richtungsentscheidungen, Kapitalallokation sowie finanzielle Vorgaben im Fokus des Vorstands stehen. Die Aufgaben der erweiterten Konzernleitung dienen der Synergiehebung im Kon\xad zern und der Verbindung der Marken und Geschäftseinheiten.', [])
#
# 76. ('Auf Konzernebene bestehen zu folgenden wesentlichen Themen Vorstandsausschüsse: Produkte, Technologien, Investitionen, Digitale Transformation, Integrität und Compliance, Risiko\xad management, Personal sowie Führungsfragen. In den Aus\xad schüssen sind neben den jeweils zuständigen Vorstandsmit\xad gliedern sowohl die relevanten Zentralbereiche als auch die relevanten Funktionen der Unternehmensbereiche vertreten.', [])
#
# 77. ('Die Ausschüsse und weitere Top-Gremien des Konzerns über\xad arbeiten und optimieren wir stetig, um zu überprüfen, ob sie weiterhin im Einklang mit unserer Unternehmensstrategie stehen und um die Effizienz ihrer Entscheidungen weiter zu steigern. Dadurch wird zum einen die Komplexität reduziert und zum anderen die Governance im Konzern gestärkt.', [])
#
# 78. ('Im Rahmen der Basisinitiative „Group Steering Model“ aus der Konzernstrategie NEW AUTO wurde auf dem Capital Markets Day im Juni 2023 ein neues Führungsmodell für den Konzern vorgestellt, das verstärkt auf Kundenorientierung, Unternehmertum und Teamgeist setzt. Es verfolgt den Grund\xad satz „Value over Volume“ und priorisiert dabei die nachhaltige Wertschöpfung über dem Volumenwachstum. Damit einher\xad gehend erhalten die Markengruppen ein neues Steuerungs\xad modell.', [])
#
# 1173. ('Änderungen in Form, Ausstattung und Technik sind jederzeit möglich. Aus den Angaben und Beschreibungen dieses Berichts können daher keine Ansprüche hergeleitet werden. Die deutsche Fassung des nichtfinanziellen Berichts ist \xadverbindlich. Die englische ist eine Überset\xadzung ausschließlich zu Informationszwecken. Ihr Feedback Wir möchten unser Nachhaltigkeitsengagement verbessern und weiterentwickeln, daher freuen wir uns über Ihr Feedback zu unserem Nachhaltigkeitsbericht.', [])
#
# 1174. ('Unter links genannter \xadE-Mail-Adresse können Sie uns Ihre Einschätzungen direkt online mitteilen. Impressum GRI 2-3 Inhalt\x08 Unternehmens-DNA | Dekarbonisierung | Kreislaufwirtschaft | Menschen in der Transformation | Vielfalt | Integrität und Compliance | Lieferkette und Menschenrechte', [])

# %% [markdown]
# # Nachhaltigkeitsversprechen herausfiltern

# %%
relevant_keywords = [
    #"verpflichtet", "verpflichten", "nachhaltigkeit","ziel","strategie",, 
    "verantwortung", "klimaneutral",  
    "2030", "klimaschutz", "emissionen",  "deklarieren", "klimaziele", 
    "co2", "paris", "klimaneutralität", "umweltziele"
]

def is_sustainability_promise_v2(chunk):
    return any(term.lower() in chunk.lower() for term in relevant_keywords)

filtered_chunks = [chunk for chunk in chunks if is_sustainability_promise_v2(chunk)]


# Ausgabe
for i, p in enumerate(filtered_chunks, 1):
    print(f"{i}. {p}\n")
# Out:
# 1. Nachhaltigkeit in der Unter­ nehmens-­DNA Dekarbonisierung Kreislauf­ wirtschaft Menschen in der Transformation Vielfalt Integrität und Compliance Lieferkette und Menschenrechte Progressive Core Sport Luxury Trucks Architecture Software Battery, Charging & Energy Volkswagen Group Mobility 06 | ESG, Decarbonization and Integrity Highlights 20231 Dekarbonisierung Zugang zu 600.000 Ladepunkten in Europa Bis 2030 soll der CO₂-Fußabdruck des gesamten Handelsnetzes um mindestens 30 % gesenkt werden.
#
# 2. Für unsere Belegschaft, unsere Kunden, unsere Investoren – und für ­unsere Gesellschaft im Ganzen. Als einer der weltweit größten Industriekonzerne tragen wir eine besondere Verantwortung. Wir können einen Unterschied machen. Diese Chance wollen und werden wir nutzen. Wir denken Nachhaltigkeit ganzheitlich – im Sinne der Natur, der Menschen, der Gesellschaft und des wertschaffenden Unternehmertums. Von der Lieferkette über unsere Produktion bis hin zur Auslieferung und Nutzung unserer Produkte.
#
# 3. Unser Ziel ist es, die Natur und die Gesellschaft positiv mitzugestal­ ten. Das ist ambitioniert. Und es wird uns Kraftanstrengungen abverlangen. Zugleich ist das Erreichen dieses Ziels eine Verpflichtung. Nach innen unseren Kolleginnen und Kollegen gegenüber und nach außen gegenüber unseren Kundinnen und Kunden, der Gesellschaft und insbesondere den künftigen Generationen. Nachhaltigkeit als Strategie: klare Ziele, klare Verantwortung Nachhaltigkeit gehört bei uns zu den Top-Prioritäten.
#
# 74. Markt Kapitalmarktperformance Eine positive CO2-Performance und kapitalmarktkon­ forme Berichterstattung können sich positiv auf Rating- Ergebnisse und Kapitalmarktkonditionen des Konzerns auswirken. Daher sind ESG-Kriterien integraler Bestand­ teil der Konzernstrategie NEW AUTO mit dem Ziel, nach­ haltige Verbesserungen der Kapitalmarktperformance zu erreichen. Ferner richtet der Konzern seine Berichter­ stattung noch konsequenter an den Anforderungen des Kapitalmarkts (zum Beispiel TCFD) aus.
#
# 75. Im Be­ richtsjahr hat der Volkswagen Konzern seinen dritten Green Finance Report veröffentlicht. Mit dem Green Finance Framework verbinden wir unser Unter­ nehmensziel der CO2-Neutralität bis 2050 mit unserer Finanzierungsstrategie. d.
#
# 76. Szenarioanalyse als Entscheidungsgrundlage für Klimaschutz Volkswagen verwendet in verschiedenen Zusammenhängen Modelldaten und -annahmen, um Aussagen über die Zukunft zu treffen.
#
# 77. Als Mitglied in der Arbeitsgruppe des Mobility Model (MoMo) der International Energy Agency (IEA) nutzen wir beispielsweise sogenannte IEA-ETP-Szenarien („Energy Technology Perspectives“), darunter das „2°C Scenario“ (2DS) GRI 201-1 Inhal Unternehmens-DNA | Dekarbonisierung | Kreislaufwirtschaft | Menschen in der Transformation | Vielfalt | Integrität und Compliance | Lieferkette und Menschenrechte 52 und das „Beyond 2°C Scenario“ (B2DS).¹ Hierbei konzentrieren wir uns auf das Zieljahr 2030, das einen Meilenstein auf dem Weg zur bilanziellen CO2-Neutralität des Konzerns bis 2050 darstellt und infolgedessen für interne KPIs als Referenz fungiert.
#
# 78. Die Szenarioanalyse legt ihren Fokus auf die Berei­ che Produktion, Vertrieb und Technologie, Auswirkungen der Produkte sowie Materialbeschaffung. Sie zeigt: Um die UN-Klimaziele zu erreichen, ist eine deutliche Verringerung der Emissionsintensität pro Fahrzeug notwendig, insbesondere vor dem Hintergrund eines steigenden Absatzes. Gleichzei­ tig wird die Elektrifizierung erheblich an Bedeutung gewinnen.
#
# 79. Dekarbonisierungsprogramm nimmt gesamten Lebenszyklus in den Blick Unser umfassendes Dekarbonisierungsprogramm schließt den gesamten Lebenszyklus der Fahrzeuge ein und zeichnet sich durch eine klare Maßnahmenhierarchie aus: An erster Stelle stehen Maßnahmen, mit denen sich CO2-Emissionen vermeiden lassen.
#
# 80. An zweiter Stelle folgen die Maßnahmen, mit denen der Konzern die Energieversorgung in der gesam­ ten Wertschöpfungskette und in allen Lebensphasen eines Fahrzeugs sukzessive auf regenerative Energie umstellt. Zu­ letzt werden in ausgewählten Fällen nicht vermeidbare CO2-Emissionen über Klimaschutzprojekte kompensiert, die höchsten internationalen Standards genügen.
#
# 81. Interne CO2-Bepreisung als Instrument zur Dekarbonisierung Wir möchten emissionsbedingte Risiken weitestgehend in strategische Entscheidungsprozesse integrieren und Reduk­ tionspfade der CO2-Flottencompliance optimieren. Zu diesem Zweck arbeiten wir im Rahmen der Portfoliosteuerung mit Schattenpreisen sowie mit einem internen Emissionshandel.
#
# 82. Im Dekarbonisierungsprogramm bewerten wir die Effizienz von Reduktionsmaßnahmen mithilfe von Vermeidungskosten und aggregieren diese in einer Vermeidungskostenkurve. Im Zuge dessen arbeiten wir aktuell mit einem internen CO2-Preis beziehungsweise Vermeidungskosten von bis zu 20 € pro t CO2. Dieser Wert wird auf Basis der Ziel­erreichung jährlich über­ prüft und durch einen Vorstandsbeschluss angepasst. Der Kostensatz im Berichtsjahr hat sich gegenüber dem Vorjahr nicht verändert.
#
# 83. Inhal Unternehmens-DNA | Dekarbonisierung | Kreislaufwirtschaft | Menschen in der Transformation | Vielfalt | Integrität und Compliance | Lieferkette und Menschenrech
#
# 90. Damit können die Emissionen aus der Nutzungsphase unserer Elektrofahrzeug­ flotte bilanziell reduziert werden. Klare Vorgaben für Dekarbonisierung in der Lieferkette Die Dekarbonisierung des Volkswagen Konzerns nimmt ihren Anfang in unseren Lieferketten. Beim Übergang zur Elektro­ mobilität werden dort zunächst höhere CO2-Emissionen ent­ stehen und sich die Anteile von der Nutzungsphase hin zur Herstellung verschieben.
#
# 91. Vor diesem Hintergrund identifizie­ ren wir systematisch die größten Treiber für CO2-Emissionen in der Lieferkette und definieren Maßnahmen zur Reduktion. Dabei sind die aufwendige Rohstoffgewinnung sowie die energieintensiven Prozesse bei der Batterieherstellung we­ sentliche Treiber. So stammt rund ein Drittel der CO2-Emis­ sionen, die bei der Fertigung eines Elektroautos entstehen, aus der Herstellung von Hochvolt-Batteriezellen (HV).
#
# 92. Alle Lieferanten (Neuvergaben) von HV-Batterien werden bereits heute vertraglich dazu verpflichtet, zertifizierten Strom aus erneuerbaren Quellen in ihrer Produktion einzusetzen. Hinzu kommen weitere Anforderungen an vorgelagerten Stufen der Wertschöpfungskette, wie zum Beispiel die im nachfolgen­ den Absatz erläuterten CO2-Grenzwerte. Damit sinkt der CO2-Ausstoß in der Batteriefertigung.
#
# 93. Weitere Informationen zu Dekarbonisierungsmaßnahmen in vorgelagerten Wert­ schöpfungsstufen sind im Kapitel Lieferkette und Menschen­ rechte verankert. Lieferkette und Menschenrechte Bei neuen Fahrzeugprojekten macht der Volkswagen Konzern die CO2-Emissionen in Zukunft zu einem technischen Merk­ mal für relevante Bauteile. Das bedeutet: Wir geben den Liefe­ ranten verbindliche CO2-Ziele vor, deren Einhaltung sie zu jeder Zeit nachweisen können müssen.
#
# 94. Ein Beispiel betrifft die neue Mechatronik-Plattform SSP. So sind die Batterien der SSP-Plattform mit einem CO2-Grenzwert versehen. Um diese Werte erreichen zu können, müssen die Lieferanten Maßnahmen in ihren eigenen Produktionsprozessen und Vor­ lieferketten umsetzen, zum Beispiel den Einsatz von erneu­ erbaren Energien. Mit Maßnahmen wie diesen lässt sich der CO2-Fußabdruck vieler Elektrofahrzeugmodelle senken.
#
# 95. Bei den ID.-Modellen setzt die Marke Volkswagen Pkw weitere nachhaltige Bauteile ein, darunter Batteriegehäuse und Felgen aus CO2-reduziertem Aluminium. So soll die CO2-Bilanz der ID.-Familie in den nächsten Jahren um rund zwei Tonnen je Fahrzeug verbessert werden. Auch die Volkswagen Group China2 arbeitet zusammen mit ihren Zulieferern an einer nachhaltigeren Lieferkette.
#
# 96. So ent­ wickelt die Gruppe zusammen mit Lieferanten und Partnern einen Fahrplan für die Umstellung auf 100 % erneuerbare Ener­ gien bis 2030. Bislang haben bereits über 500 Zulieferer ­eine Erklärung unterschrieben, mit der sie sich zur Umstellung auf Strom aus erneuerbaren Energien verpflichten.
#
#
# 273. Verantwortung des Wirtschaftsprüfers Unsere Aufgabe ist es, auf Grundlage der von uns durchge­ führten Prüfung ein Prüfungsurteil mit begrenzter Sicherheit über die nichtfinanzielle Berichterstattung abzugeben. Wir haben unsere betriebswirtschaftliche Prüfung unter Be­ achtung des International Standard on Assurance Engage­ ments (ISAE) 3000 (Revised): „Assurance Engagements other than Audits or Reviews of Historical Financial Information“, herausgegeben vom IAASB, durchgeführt.
#
# 274. Verwendungsbeschränkung für den Vermerk Wir weisen darauf hin, dass die Prüfung für Zwecke der Ge­ sellschaft durchgeführt und der Vermerk nur zur Information der Gesellschaft über das Ergebnis der Prüfung bestimmt ist. Folglich ist er möglicherweise für einen anderen als den vor­ genannten Zweck nicht geeignet. Somit ist der Vermerk nicht dazu bestimmt, dass Dritte hierauf gestützt (Vermögens-) Entscheidungen treffen. Unsere Verantwortung besteht allein der Gesellschaft gegenüber.
#
# 275. Dritten gegenüber übernehmen wir dagegen keine Verantwortung. Unser Prüfungsurteil ist in dieser Hinsicht nicht modifiziert. Auftragsbedingungen und Haftung Für diesen Auftrag gelten, auch im Verhältnis zu Dritten, die beigefügten „Allgemeinen Auftragsbedingungen für Wirt­ schaftsprüfer und Wirtschaftsprüfungsgesellschaften“ in der vom Institut der Wirtschaftsprüfer herausgegebenen Fassung vom 1. Januar 2017 (www.de.ey.com/IDW-­ Auftragsbedingungen).

# %%
pip install sentencepiece
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (7.7 kB)
# Downloading sentencepiece-0.2.0-cp310-cp310-macosx_10_9_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("paraphrase-MiniLM-L6-v2")
kw_model = KeyBERT(model=model)

zusammenfassungen = []
for chunk in filtered_chunks:
    keywords = kw_model.extract_keywords(chunk, keyphrase_ngram_range=(1, 10), stop_words=None, top_n=10)
    print(keywords)
    zusammenfassungen.append(keywords)
    

for kw in keywords:
    print(f"- {kw[0]} (Score: {kw[1]:.3f})")
# Out:
# [('compliance lieferkette und menschenrechte progressive core sport luxury trucks architecture', 0.6677), ('und compliance lieferkette und menschenrechte progressive core sport luxury trucks', 0.6645), ('compliance lieferkette und menschenrechte progressive core sport luxury trucks', 0.6412), ('lieferkette und menschenrechte progressive core sport luxury trucks architecture', 0.6277), ('und menschenrechte progressive core sport luxury trucks architecture software battery', 0.6276), ('lieferkette und menschenrechte progressive core sport luxury trucks architecture software', 0.6262), ('und menschenrechte progressive core sport luxury trucks architecture', 0.6125), ('lieferkette und menschenrechte progressive core sport luxury trucks', 0.6002), ('menschenrechte progressive core sport luxury trucks architecture software battery', 0.5968), ('und menschenrechte progressive core sport luxury trucks architecture software', 0.5905)]
# [('unsere investoren und für unsere gesellschaft im ganzen als einer', 0.8298), ('investoren und für unsere gesellschaft im ganzen als einer der', 0.8252), ('kunden unsere investoren und für unsere gesellschaft im ganzen als', 0.8243), ('investoren und für unsere gesellschaft im ganzen als einer', 0.8207), ('kunden unsere investoren und für unsere gesellschaft im ganzen', 0.8136), ('unsere kunden unsere investoren und für unsere gesellschaft im ganzen', 0.8089), ('unsere investoren und für unsere gesellschaft im ganzen als', 0.8028), ('unsere gesellschaft im ganzen als einer der weltweit größten industriekonzerne', 0.8012), ('unsere investoren und für unsere gesellschaft im ganzen', 0.7916), ('kunden unsere investoren und für unsere gesellschaft im', 0.7831)]
# [('impulse der volkswagen konzern ist sich seiner rolle bedeutung und', 0.8832), ('der volkswagen konzern ist sich seiner rolle bedeutung und verantwortung', 0.8767), ('der volkswagen konzern ist sich seiner rolle bedeutung und', 0.8712), ('setzen wir hier wichtige und zielführende neue impulse der volkswagen', 0.8705), ('und zielführende neue impulse der volkswagen konzern ist sich seiner', 0.8645), ('wir hier wichtige und zielführende neue impulse der volkswagen konzern', 0.8607), ('hier wichtige und zielführende neue impulse der volkswagen konzern ist', 0.8596), ('volkswagen konzern ist sich seiner rolle bedeutung und verantwortung', 0.8589), ('volkswagen konzern ist sich seiner rolle bedeutung und verantwortung bewusst', 0.8561), ('hier wichtige und zielführende neue impulse der volkswagen konzern', 0.8552)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 7
#       5 zusammenfassungen = []
#       6 for chunk in filtered_chunks:
# ----> 7     keywords = kw_model.extract_keywords(chunk, keyphrase_ngram_range=(1, 10), stop_words=None, top_n=10)
#       8     print(keywords)
#       9     zusammenfassungen.append(keywords)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/keybert/_model.py:199, in KeyBERT.extract_keywords(self, docs, candidates, keyphrase_ngram_range, stop_words, top_n, min_df, use_maxsum, use_mmr, diversity, nr_candidates, vectorizer, highlight, seed_keywords, doc_embeddings, word_embeddings, threshold)
#     197     doc_embeddings = self.model.embed(docs)
#     198 if word_embeddings is None:
# --> 199     word_embeddings = self.model.embed(words)
#     201 # Guided KeyBERT either local (keywords shared among documents) or global (keywords per document)
#     202 if seed_keywords is not None:
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/keybert/backend/_sentencetransformers.py:65, in SentenceTransformerBackend.embed(self, documents, verbose)
#      53 """Embed a list of n documents/words into an n-dimensional
#      54 matrix of embeddings.
#      55
#    (...)
#      62     that each have an embeddings size of `m`
#      63 """
#      64 self.encode_kwargs.update({"show_progress_bar": verbose})
# ---> 65 embeddings = self.embedding_model.encode(documents, **self.encode_kwargs)
#      66 return embeddings
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:685, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, **kwargs)
#     682 features.update(extra_features)
#     684 with torch.no_grad():
# --> 685     out_features = self.forward(features, **kwargs)
#     686     if self.device.type == "hpu":
#     687         out_features = copy.deepcopy(out_features)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:758, in SentenceTransformer.forward(self, input, **kwargs)
#     756     module_kwarg_keys = self.module_kwargs.get(module_name, [])
#     757     module_kwargs = {key: value for key, value in kwargs.items() if key in module_kwarg_keys}
# --> 758     input = module(input, **module_kwargs)
#     759 return input
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/sentence_transformers/models/Transformer.py:442, in Transformer.forward(self, features, **kwargs)
#     435 """Returns token_embeddings, cls_token"""
#     436 trans_features = {
#     437     key: value
#     438     for key, value in features.items()
#     439     if key in ["input_ids", "attention_mask", "token_type_ids", "inputs_embeds"]
#     440 }
# --> 442 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     443 token_embeddings = outputs[0]
#     444 features["token_embeddings"] = token_embeddings
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:1016, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1009 # Prepare head mask if needed
#    1010 # 1.0 in head_mask indicate we keep the head
#    1011 # attention_probs has shape bsz x n_heads x N x N
#    1012 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1013 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1014 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1016 encoder_outputs = self.encoder(
#    1017     embedding_output,
#    1018     attention_mask=extended_attention_mask,
#    1019     head_mask=head_mask,
#    1020     encoder_hidden_states=encoder_hidden_states,
#    1021     encoder_attention_mask=encoder_extended_attention_mask,
#    1022     past_key_values=past_key_values,
#    1023     use_cache=use_cache,
#    1024     output_attentions=output_attentions,
#    1025     output_hidden_states=output_hidden_states,
#    1026     return_dict=return_dict,
#    1027 )
#    1028 sequence_output = encoder_outputs[0]
#    1029 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:662, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     651     layer_outputs = self._gradient_checkpointing_func(
#     652         layer_module.__call__,
#     653         hidden_states,
#    (...)
#     659         output_attentions,
#     660     )
#     661 else:
# --> 662     layer_outputs = layer_module(
#     663         hidden_states,
#     664         attention_mask,
#     665         layer_head_mask,
#     666         encoder_hidden_states,
#     667         encoder_attention_mask,
#     668         past_key_value,
#     669         output_attentions,
#     670     )
#     672 hidden_states = layer_outputs[0]
#     673 if use_cache:
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:594, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     591     cross_attn_present_key_value = cross_attention_outputs[-1]
#     592     present_key_value = present_key_value + cross_attn_present_key_value
# --> 594 layer_output = apply_chunking_to_forward(
#     595     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     596 )
#     597 outputs = (layer_output,) + outputs
#     599 # if decoder, return the attn key/values as the last output
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/pytorch_utils.py:253, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     250     # concatenate output at same dimension
#     251     return torch.cat(output_chunks, dim=chunk_dim)
# --> 253 return forward_fn(*input_tensors)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:606, in BertLayer.feed_forward_chunk(self, attention_output)
#     605 def feed_forward_chunk(self, attention_output):
# --> 606     intermediate_output = self.intermediate(attention_output)
#     607     layer_output = self.output(intermediate_output, attention_output)
#     608     return layer_output
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:506, in BertIntermediate.forward(self, hidden_states)
#     505 def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# --> 506     hidden_states = self.dense(hidden_states)
#     507     hidden_states = self.intermediate_act_fn(hidden_states)
#     508     return hidden_states
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

model_name = "facebook/bart-large-cnn"

# Modell und Tokenizer laden
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=False)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
summarizer = pipeline("summarization", model=model, tokenizer=tokenizer)

# Zusammenfassungen erzeugen
zusammenfassungen = []
for chunk in filtered_chunks:
    summary = summarizer(chunk, max_length=80, min_length=30, do_sample=False)[0]["summary_text"]
    print(summary)
    zusammenfassungen.append(summary)

finale_zusammenfassung = " ".join(zusammenfassungen)

# Ausgabe
print("Einzelne Zusammenfassungen:")
for i, z in enumerate(zusammenfassungen, 1):
    print(f"\nChunk {i}:\n{z}")

print("\n--- Finale Gesamtzusammenfassung ---\n")
print(finale_zusammenfassung)
# Out:
# Device set to use cpu
# Bis 2030 soll der CO₂-Fußabdruck des gesamten Handelsnetzes um mindestens 30 % gesenkt werden. Volkswagen Group Mobility 06 | ESG, Decarbonization and Integrity Highlights 20231.
# "Wir denken Nachhaltigkeit ganzheitlich – im Sinne der Natur, der Menschen, der Gesellschaft and des wertschaffenden Unternehmertums" "Wir können einen Unterschied machen. Diese Chance wollen und werden wir
# Unser Ziel ist es, die Natur und die Gesellschaft positiv mitzugestal­ ten. Das ist ambitioniert. Und es wird uns Kraftanstrengungen abverlangen. Zugleich ist das Erreichen dieses Ziels eine Verpflichtung. Nachhalt
# Volkswagen ist in der persönlichen Verantwortung des Managements, diese einzuhalten. Alle Ziele werden systematisch auf die Marken und Konzern­ gesellschaften heruntergebrochen.
# Volkswagen: Die produktionsbedingten ­CO2-Emissionen von Pkw und leichten Nutzfahrzeugen bis 2030 um 50,4 Prozent im Vergleich zum Basisjahr 2018 zu reduce.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 13
#      11 zusammenfassungen = []
#      12 for chunk in filtered_chunks:
# ---> 13     summary = summarizer(chunk, max_length=80, min_length=30, do_sample=False)[0]["summary_text"]
#      14     print(summary)
#      15     zusammenfassungen.append(summary)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/pipelines/text2text_generation.py:298, in SummarizationPipeline.__call__(self, *args, **kwargs)
#     274 def __call__(self, *args, **kwargs):
#     275     r"""
#     276     Summarize the text(s) given as inputs.
#     277
#    (...)
#     296           ids of the summary.
#     297     """
# --> 298     return super().__call__(*args, **kwargs)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/pipelines/text2text_generation.py:186, in Text2TextGenerationPipeline.__call__(self, *args, **kwargs)
#     157 def __call__(self, *args, **kwargs):
#     158     r"""
#     159     Generate the output text(s) using text(s) given as inputs.
#     160
#    (...)
#     183           ids of the generated text.
#     184     """
# --> 186     result = super().__call__(*args, **kwargs)
#     187     if (
#     188         isinstance(args[0], list)
#     189         and all(isinstance(el, str) for el in args[0])
#     190         and all(len(res) == 1 for res in result)
#     191     ):
#     192         return [res[0] for res in result]
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/pipelines/base.py:1431, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1423     return next(
#    1424         iter(
#    1425             self.get_iterator(
#    (...)
#    1428         )
#    1429     )
#    1430 else:
# -> 1431     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/pipelines/base.py:1438, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1436 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1437     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1438     model_outputs = self.forward(model_inputs, **forward_params)
#    1439     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1440     return outputs
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/pipelines/base.py:1338, in Pipeline.forward(self, model_inputs, **forward_params)
#    1336     with inference_context():
#    1337         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1338         model_outputs = self._forward(model_inputs, **forward_params)
#    1339         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1340 else:
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/pipelines/text2text_generation.py:215, in Text2TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     212 if "generation_config" not in generate_kwargs:
#     213     generate_kwargs["generation_config"] = self.generation_config
# --> 215 output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     216 out_b = output_ids.shape[0]
#     217 if self.framework == "pt":
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/generation/utils.py:2616, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2609     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2610         input_ids=input_ids,
#    2611         expand_size=generation_config.num_beams,
#    2612         is_encoder_decoder=self.config.is_encoder_decoder,
#    2613         **model_kwargs,
#    2614     )
#    2615     # 12. run beam sample
# -> 2616     result = self._beam_search(
#    2617         input_ids,
#    2618         logits_processor=prepared_logits_processor,
#    2619         stopping_criteria=prepared_stopping_criteria,
#    2620         generation_config=generation_config,
#    2621         synced_gpus=synced_gpus,
#    2622         **model_kwargs,
#    2623     )
#    2625 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    2626     # 11. prepare beam search scorer
#    2627     beam_scorer = BeamSearchScorer(
#    2628         batch_size=batch_size,
#    2629         num_beams=generation_config.num_beams,
#    (...)
#    2635         max_length=generation_config.max_length,
#    2636     )
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/generation/utils.py:4024, in GenerationMixin._beam_search(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    4021 while self._has_unfinished_sequences(this_peer_finished, synced_gpus, device=input_ids.device):
#    4022     # a. Forward current tokens, obtain the logits
#    4023     flat_running_sequences = self._flatten_beam_dim(running_sequences[:, :, :cur_len])
# -> 4024     model_inputs = self.prepare_inputs_for_generation(flat_running_sequences, **model_kwargs)
#    4026     # prepare variable output controls (note: some models won't accept all output controls)
#    4027     model_inputs.update({"output_attentions": output_attentions} if output_attentions else {})
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/generation/utils.py:682, in GenerationMixin.prepare_inputs_for_generation(self, input_ids, past_key_values, attention_mask, inputs_embeds, cache_position, **kwargs)
#     679         model_inputs[key] = value
#     681 # 8. Remove unexpected `generate` inputs (TODO @joao: fix trainer and examples)
# --> 682 model_inputs.pop("labels", None)
#     683 return model_inputs
#
# KeyboardInterrupt:

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------

# %%
print("Einzelne Zusammenfassungen:")
for i, z in enumerate(zusammenfassungen, 1):
    print(f"\nChunk {i}:\n{z}")
# Out:
# Einzelne Zusammenfassungen:
#
# Chunk 1:
# Nachhaltigkeitswirkungen neuer Mobilitätsangebote 30 Stakeholder-Management 33 Umwelt-Compliance-Management 42 Risikomanagement 45 Corporate Citizenship Fokusthemen 1   Dekarbonisierung 48 Dekarbonisie 69 EU-Taxonomie 2   Kreislaufwirtschaft 83 KreislauFWirtschafts 3   Menschen in der Transformation
#
# Chunk 2:
# Konzernstrategie NEW AUTO stellen uns zukunftsgerichtet auf. Dabei behalten wir unser Ziel, ein weltweit führender Anbieter nachhaltiger Mobilität. richten den Konzern fokussierter, effizienter, innovativer.
#
# Chunk 3:
# Konzernstrategie NEW AUTO definiert für den Bereich Nachhaltigkeit und ESG in der Konzerninitiative 6 die sechs oben ab­gebil­deten wesentlichen Fokusthemen. Nach diesen ist der vorliegende Nach hartigkeitsbericht inklusive nichtfinanzieller Bericht.
#
# Chunk 4:
# Ein Einblick in Themen wie Risikomanagement, Umweltmanagement, Stakeholder-Management und Corporate Citizenship. Eine Definition von Nachhaltigkeit für das Unternehmen.
#
# Chunk 5:
# Bis 2030 soll der CO₂-Fußabdruck des gesamten Handelsnetzes um mindestens 30 % gesenkt werden. Volkswagen Group Mobility 06 | ESG, Decarbonization and Integrity Highlights 20231.
#
# Chunk 6:
# Mehr als 850.000 t CO₂ wurden seit 2017 durch den Aluminium-­ Closed-Loop bilanziell eingespart. 72 Standorte des Volkswagen Konzerns sind nach ISO 45001 zertifiziert. Vielfalt 94 % der Führungskräfte haben am ­Diversity Wins @ Volkswagen ­Programm teilgenommen.
#
# Chunk 7:
# Weltweit Frauenanteile im Management und Internationalität im Top-Management gesteigert 2023. 1.551 Anfragen hat der Infopoint ­Compliance bearbeitet. 7.791 direkte Lieferanten wurden weltweit zu Nachhaltigkeit geschult.
#
# Chunk 8:
# "Wir denken Nachhaltigkeit ganzheitlich – im Sinne der Natur, der Menschen, der Gesellschaft and des wertschaffenden Unternehmertums" "Wir können einen Unterschied machen. Diese Chance wollen und werden wir nutzen"
#
# Chunk 9:
# Unser Ziel ist es, die Natur und die Gesellschaft positiv mitzugestal­ ten. Das ist ambitioniert. Und es wird uns Kraftanstrengungen abverlangen. Zugleich ist das Erreichen dieses Ziels eine Verpflichtung.
#
# Chunk 10:
# Volkswagen ist in der persönlichen Verantwortung des Managements, diese einzuhalten. Alle Ziele werden systematisch auf die Marken und Konzern­ gesellschaften heruntergebrochen.
#
# Chunk 11:
# Volkswagen: Die produktionsbedingten ­CO2-Emissionen von Pkw und leichten Nutzfahrzeugen bis 2030 um 50,4 Prozent im Vergleich zum Basisjahr 2018 zu reduce.
#
# Chunk 12:
# Science Based Targets Initiative (SBTi) bestätigt, die Erderwärmung auf 1,5 Grad Celsius zu begrenzen. Das Ziel, die CO2-Emissionen in der Nutzungsphase (Scope 3) um 30 Prozent zu reduzieren, ist durch SBTi als konform.
#
# Chunk 13:
# Volkswagen strebt bis zum Jahr 2030 eine Sen­ kung des durchschnittlichen CO2-Ausstoßes pro Fahrzeug. Dabei gehen der Hochlauf der Elektromobilität and der Ausbau von erneuerbaren Energien Hand in Hand.
#
# Chunk 14:
# Arbeitgeberattraktivität ist essenziell für die Zukunftsfähigkeit von Unternehmen. Arbeits­ plätze werden neu ausgerichtet, neue ArbeITSfelder entstehen, andere entfallen dauerhaft.
#
# Chunk 15:
# Arbeitgeberattraktivität ist längst keine reine Frage des Gehalts mehr. Talente bewerten bei potenziellen Arbeitgebern genauso Faktoren wie Flexibilität.
#
# Chunk 16:
# Die Verantwortung für ‘Menschen in der Transforma­ tion’ steht im Zentrum aktueller und zukünftiger Aktivitäten im Personalbereich. Eine Schlüsselrolle spielt die 2021 vom Konzernvorstand verabschiedete Group People Strategy ‘Transform to Tech’
#
# Chunk 17:
# Volkswagen Group Academy ist berufliches Qualifizierungs­ programm gezielt um Kurse zur E-Mobilität.
#
# Chunk 18:
# Beschäftigungssicherung bis 2029 in der Volkswagen AG gibt dabei den notwendigen Rückhalt. Sie sollen den Menschen eine Perspektive geben und in der Transformation eine klare Richtung für den Veränderungsprozes vorgeben.
#
# Chunk 19:
# Das Lieferkettensorgfaltspflichtengesetz, seit einem guten Jahr in Deutschland in Kraft, hat hier eine besondere Rolle. Schwerpunkte sind der Schutz der Menschenrechte und die Minimierung umweltbezogener Risiken.
#
# Chunk 20:
# Volkswagen ist seit vielen Jahrzehnten ein Tech­ nologieunternehmen. Diese Kompetenz werden wir auch in der Nachhaltigkeit nutzen.
#
# Chunk 21:
# Nachhaltigkeit ist tief im Selbstverständnis des Volkswagen Konzerns. Sie ist fester Bestandteil unserer Konzer­ strategie. Heute befinden wir uns in der größten Transformation der Automobilgeschichte.
#
# Chunk 22:
# Für 2024 setzen wir hier wichtige und zielführende neue Impulse. Der Volkswagen Konzern ist sich seiner Rolle, Bedeutung und Verantwortung bewusst. Gemeinsam werden wir alles dafür tun, unseren wichtigen Beitrag zu leisten.
#
# Chunk 23:
# Der vorliegende Konzern-Nachhaltigkeitsbericht 2023 ori­ entiert sich an international etablierten Rahmenwerken.
#
# Chunk 24:
# Der Bericht wird durch eine ausführliche Darstellung der Nachhaltigkeitsaktivitäten der Marken und Regionen ergänzt. Weitergehende und insbesondere für ESG-Investoren rele­ vante Informationen finden sich auf der Corporate Website des Konzerns.
#
# Chunk 25:
# Die Volkswagen AG gibt für das Berichtsjahr 2023 eine nicht­ finanzielle Erklärung auf Gesellschaftsebene. Der nichtfinanzielle Bericht ist in Übereinstimmung mit den §§ 315c i. m. 289c bis 289e HGB aufgestellt.
#
# Chunk 26:
# CSR-RUG konzentriert sich der vorliegende nichtfinan­ zielle Bericht auf Fokusthemen. Unsere Aktivitäten zum Klimaschutz berichten wir er­ neut entlang der Task Force on Climate-related Financial Disclosures (TCFD)
#
# Chunk 27:
# Innerhalb dieses Nachhaltigkeitsberichts legt Volkswagen grundsätzlich die GRI-Standards (unter Bezugnahme) als Rahmenwerk für die Berichterstattung der Managementansätze. Darüber hinaus werden die Gri-Stand Standards als. Rahmen werk f for die Erstellung des nichtfinanzie
#
# Chunk 28:
# Der GRI-Inhaltsindex wird aus dem Nachhaltigkeitsbericht 2023 ausgegliedert. Der Bericht ist eigenständiges Dokument im Konzernportal veröffentlicht.
#
# Chunk 29:
# Risiken des chinesischen Markts werden über die Volkswagen (China) Investment Company Ltd. erfasst. Die dargestellten Kennzahlen führen jene der Vorjahre fort. Wesentliche Änderungen in der Datenerhebung und in den Messverfahren für unsere Nachhaltigkeitsleistungen werdet an den jew
#
# Chunk 30:
# Nichtfinanzielle Bericht nach ISAE 3000 (Revised) unterzogen. EY GmbH & Co. KG Wirtschaftsprüfungsgesellschaft gegen relevanten ge­ setzlichen Anforderungen.
#
# Chunk 31:
# Im Geschäftsjahr 2023 waren im Zusammenhang mit der Dieselthematik keine wesentlichen Sondereinflüsse zu er­ fassen. Weitere Informationen zur Prüfung finden Sie im Vermerk des unabhängigen Wirt­ schaftsprüfers.
#
# Chunk 32:
# Sollten sich diese Rechts- beziehungsweise Einschätzungsrisiken verwirklichen, kann dies zu weiteren erheblichen finanziellen Belastungen führen. Als Mitglied des Global Compact der Vereinten Nationen (UN Global Compact) berichten wir außerdem kontinuierlich, wie wir
#
# Chunk 33:
# Berichts bestehen je aus einem Textteil sowie einer konsoli­ dierten Kennzahlentabelle. Verweise auf Angaben außerhalb des nichtfinanziellen Be­ richts sind weiterführende Informationen und nicht Bestand­ teil.
#
# Chunk 34:
# Die Angaben in diesem Bericht beziehen sich auf den ge­ samten Volkswagen Konzern. Ebenso sind folgende Passagen nicht Bestandteil des nichtfinanziellen Berichts. Nachhaltigkeitskommunikation des Volkswagen ­Konzerns.
#
# Chunk 35:
# Themen Umweltentlastung Produktion (UEP), Dekarbo­ nisierungsindex (DKI), Stimmungsbarometer, Diversity-Index, GRI 2-2,. 2-4, 2-5 Inhalt lässt sich nicht ausschließen.
#
# Chunk 36:
# Alle infolge der Richtlinie 2014/95/EU zur Offenlegung von nichtfinanziellen und die Diversität betreffenden Informationen auf Basis nationaler Gesetzgebung verpflichteten Konzern­ gesellschaften, die keine eigene nicht Finanzielle Erklärung abgeben.
#
# Chunk 37:
# Die Verwendung des Begriffs CO2-Emissionen in diesem Be­ richt schließt die Betrachtung und Ermittlung weiterer klima­ schädlicher Treibhausgase. Dies gilt nicht für die Werte der Flottenemissionen.
#
# Chunk 38:
# Bilanzielle CO2-Neutralität wird erreicht, wenn anthropogene CO3-Emissionen weltweit durch die Vermeidung, Reduktion und Kompensation über einen spezifischen Zeitraum ausge­ glichen werden. Beim Klimaschutz achtet Volkswagen neben CO2  auch auf alle anderen relevanten
#
# Chunk 39:
# Nachhaltigkeitsbericht schließt bei jeder Nennung den nichtfinan­ ziellen Bericht in dem auf S. 10 beschriebenen Umfang mit ein. Gleiches gilt für ähnliche Begriffe wie Teil­ nehmer, Vertreter, Lieferant etc.
#
# Chunk 40:
# Der letzte nichtfinanzielle Bericht wurde am 12. März 2023 veröffent­ licht. Der Bericht enthält neben den Nachhaltigkeitsaktivitäten des Konzerns.
#
# Chunk 41:
# Der Konzern-Nachhaltigkeitsbericht wird im ersten Quartal 2024 veröffentlicht. Die deutsche maßgeb­ liche Fassung des Dokuments liegt in englischer Über­ setzung vor.
#
# Chunk 42:
# Einschätzungen zu den ­Faktoren nachhaltiger Wertsteigerung sowie zu Risiken und Chancen anders entwickeln als derzeit von uns erwartet. Darüber hinaus kann es also zu Abweichungen von der voraussichtlichen Geschäftsentwicklung kommen.
#
# Chunk 43:
# Inhalt: Nachhaltigkeit in der Unternehmens-DNA 13 Corporate Governance 17 Konzernstrategie NEW AUTO 22 ESG-Performance-Management und Wesentlichkeitsanalyse 25 NachHaltigKEitsmanagement 27. Inhalt 2: Lieferkette und Menschenrechte.
#
# Chunk 44:
# Volkswagen AG ist vertikal integriertes Energieversor­ gungsunternehmen. Unterliegt somit den Regelungen des EnWG. Im Elektrizitätssektor übt die Volkswagen AG gemein­ sam in der Gruppe.
#
# Chunk 45:
# Ihre Struktur trägt dazu bei, dass wesentliche Aufgaben wie Strategie, zentrale Richtungsentscheidungen, Kapitalallokation sowie finanzielle Vorgaben im Fokus des Vorstands stehen.
#
# Chunk 46:
# Die Ausschüsse und weitere Top-Gremien des Konzerns über­ arbeiten. Dadurch wird zum einen die Komplexität reduziert. Zum anderen die Governance imKonzern gestärkt.
#
# Chunk 47:
# Ein neues Führungsmodell für den Konzern wurde auf dem Capital Markets Day im Juni 2023 vorgestellt. Es verstärkt auf Kundenorientierung, Unternehmertum and Teamgeist setzt.
#
# Chunk 48:
# Konzerns strategie ist ein hoher Grad an unternehmerischer Verantwortung in den Marken­ gruppen und Technologieplattformen.
#
# Chunk 49:
# The Re­ gierungskommission hat die Grundsätze, Empfehlungen und Anregungen des DCGK auf Basis wesentlicher Vorschriften sowie national und international anerkannter Standards guter und verantwortungsvoller Unternehmensführung erarbeitet.
#
# Chunk 50:
# Konzernübergreifende Interessen können so ver­ folgt und gleichzeitig die markenindividuellen Charakteristika gewahrt. Angelegenheiten von konzern­ weiter Bedeutung werden vorgelegt.
#
# Chunk 51:
# Gesellschaften des Volkswagen Konzerns werden von ihrer jeweiligen Geschäftsleitung in eigener Verantwortung geführt. Die Rechte und Pflichten der gesetz­ lichen Organe der betreffenden Markengesellschaft bleiben davon unberührte.
#
# Chunk 52:
# Produktion Je Arbeitstag wurden 2023 durchschnittlich rund über 26.660 Fahrzeuge gefertigt. Effizienz in der Produktion ist ein zentrales Ziel, ebenso wie Umweltschutz, Gesundheit und Sicherheit.
#
# Chunk 53:
# Konzernstrategie ‘NEW AUTO – Mobility for genera­ tions to come’ beschlossen. Fokus auf die Mobilitätswelt im Jahr 2030. GRI 2-6, 207-4 Inhalt von Unternehmens-DNA.
#
# Chunk 54:
# Nachhaltigkeit wird weiterhin ein Leitmotiv für das wirtschaft­ liche Handeln sein. Treiber hierfür sind die zunehmend wahrnehmbaren Folgen des Klimawandels.
#
# Chunk 55:
# Volkswagen Group ­Mobility ist ein weltweit führender Anbieter nachhaltiger Mobilität. Wir richten den Konzern fokussierter, effizienter, innovativer, kundennäher.
#
# Chunk 56:
# Für die unterjährige Operationalisierung der Strategie werden die wichtigsten Ziele jedes Kalenderjahres definiert. Ein be­ sonderes Augenmerk lag für 2023 im Rahmen des Konzern TOP 10 Programms.
#
# Chunk 57:
# Diese TOP-10- Programm-­Methodik wurde von vielen Bereichen in deren Funktionalbereichsstrategien übernommen. Wird zur be­ schleunigten Umsetzung der Strategie mit hohem Fokus ver­ wendet.
#
# Chunk 58:
# Konzernvorstand ent­ schieden, die strategischen Ziele und Meilensteine mittels der OKR-Methode (Objectives and Key Results) zu struktu­ rieren.
#
# Chunk 59:
# Dementsprechend werden Konzernstrategie NEW AUTO Inhalt 18 für allen Fokusthemen strategische Ziele (Objectives) und anvisierte Zwischenergebnisse (Key Results) definiert. Diese sollen im Wesent­lichen durch zeitlich limitierte Projekte und Arbeitspakete realisiert.
#
# Chunk 60:
# Der Er­reichungsgrad wird in der Regel drei­ mal jährlich dem Vorstand aufgezeigt. So werden die Rele­ vanz der Fokusthemen, deren Ziele und Meilensteine sowie Projekte und Arbeits­pakete ­regelmäßig auf Konzernebene überprüft.
#
# Chunk 61:
# Eine zukunftsorientierte Mechatronikplattform soll das Rückgrat für Innovationen, Technologien und die nachhaltige Wettbewerbsfähigkeit bei Volkswagen bilden.
#
# Chunk 62:
# CARIAD arbeitet mit führenden Technologieunternehmen ­zusammen, um weitere innovative Lösungen zu integrieren. Dabei verfolgen wir die folgende Strategie: Software für zentrale Kontrollpunkte im Fahrzeug wollen wir selbst oder gemeinsam in strategischen Partnerschaften entwickeln
#
# Chunk 63:
# Architektur E³ 2.0 stellt mit ihrem softwarezentrierten Ansatz einen ­Paradigmenwechsel in der Fahrzeugentwicklung dar. Sie soll die Grundlage für Software Defined Vehicles des Volkswagen Konzerns bilden.
#
# Chunk 64:
# “Cell and Battery Strategy’ treibt den Transformations­ prozess zusammen mit unseren strategischen Partnern voran. Da­ zu bündelt die Tech-Initiative „Cell and battery Strategy“ konzernweites Know-how“
#
# Chunk 65:
# Batterie­ zelltechnologie – zusammen mit Partnern – ist zu einer Kern­ kompetenz im Konzern auszubauen. Dies umfasst unter anderem die Batterieentwicklung, die Zell­ produktion, die vertikale Integration, Großspeichersysteme und das Recycling.
#
# Chunk 66:
# So soll der rasant ansteigende Bedarf an Batteriezellen bis 2030 etwa zur Hälfte gedeckt werden. Daher streben wir an, zukünftig ein ganzheitlicher Lade- und Energieservicedienstleister zu sein.
#
# Chunk 67:
# Ladedienste und smarte Ökostrom-Tarife in den Mittelpunkt. Ladevorgänge sollen dann gezielt so gesteuert werden, dass erneuerbare Energien geladen.
#
# Chunk 68:
# Wir bekennen uns zum Pariser Klimaschutzabkommen. Wir richten unsere ei­ genen Aktivitäten am 1,5-Grad-Ziel aus. Bis 2050 beabsich­ tigen wir, ein bilanziell CO2-neutrales Unternehmen zu sein.
#
# Chunk 69:
# Fahrzeuglebenszyklus soll bis 2030 in einem Großteil der plattform­ basierten Fahrzeuge integriert sein. Dienste und Funkti­ onen anzubieten, die auf deren individuelle Bedürfnisse ein­ gehen. Konzerns Marken sollen mit Kunden über den gesamten Fahr
#
# Chunk 70:
# Bis 2030 soll Nordamerika zur dritten Kernregion neben ­Europa und China werden. So kann ein wettbewerbsfähiges, datengetriebenes Serviceportfolio aufgebaut.
#
# Chunk 71:
# "Unser Ziel ist es, dort bis dahin den Gesamt­ marktanteil des Volkswagen Konzerns sehr stark zu steigern. Wir streben an, uns mit starken Marken in der Region weiter­ zuentwickeln"
#
# Chunk 72:
# "Wollen wir überproportional am Wachstum zunehmend elektrifizierter Märkte in den USA und Kanada partizipieren" "Unser konzernweites Angebot an vollelektrischen Modellen massiv ausbauen"
#
# Chunk 73:
# So soll der Anteil batterieelektrischer Fahrzeuge an unseren Verkäufen in den USA und Kanada bis 2030 auf 55 % steigen. Zusätzlich wollen wir das Synergiepotenzial in der Region maximieren.
#
# Chunk 74:
# Unser Ziel ist es, im Jahr 2030 in China eine führende Rolle als internationaler Mobilitätsanbieter. Im Rahmen unserer Lokalisierungsstrategie (in China für China) wollen wir des­ halb in den kommenden Jahren unsere lokalen Entwicklungs­ kapazitäten stärker bü
#
# Chunk 75:
# Volkswagen ist eine weitreichende Optimierung unseres Konzern­ steuerungsmodells vor. Es ist essenziell, dass Mechanismen zur schnellen Entscheidungsfindung, zur Entwicklung und Anwendung von Plattformtechnologien sowie zur Hebung von Synergien auf konstant hohem Level etabliert
#
# Chunk 76:
# Das aktualisierte Konzernsteue­ rungsmodell stellt die Markengruppen und die Technologie­ plattformen in den Vordergrund. Auf dieser Logik baut ein neuer effizienzoptimierter Strategie- und Produktplanungsprozess auf.
#
# Chunk 77:
# "Wir wollen ein Umfeld für leistungsfähige Teams schaffen und fördern" "Unternehmenskultur mündet, die das Zusammengehörigkeitsgefühl und die Loyalität zum Unter­ nehmen unterstützt"
#
# Chunk 78:
# Konzern zum Ziel gesetzt, nachhaltig seine Fixkostenstruktur, die Produktivität der Werke, die Kosten der Beschaffung, die VertriebsKosten und das Working-­ Capital Management zu optimieren. Strategische Finanzkennzahlen 2022 Ziel 2030 Operative Umsatzrendite 8,1 % 9 bis 11
#
# Chunk 79:
# 22 Wesentlichkeitsanalyse mit Konzernstrategie und ESG-Performance verknüpft. Wichtigsten Nachhaltigkeitsthemen identifiziert und be­ wertet.
#
# Chunk 80:
# Fokus ist auf wesent­ lichen ESG-Anforderungen, Erwartungen von Stakeholdern sowie der Beachtung gesetzlicher Vorschriften. Das Unternehmen hat im Jahr 2022 eine Wesentlichkeits­ analyse durchgeführt.
#
# Chunk 81:
# Basis hierfür waren: Ergebnisse des Dialogprozesses sowie dem Stakeholder-Panel. Anforderungen aus maßgeblichen internationalen und nationalen Rahmenwerken wie etwa der EU-Taxonomie, dem Handelsgesetzbuch (HGB)
#
# Chunk 82:
# Fokus­ themen wurden mit der Wesentlichkeitsanalyse 2022 be­ stätigt. Die fünf nichtfinanziellen Belange, die sich aus dem CSR-Richtlinie-Umsetzungsgesetz ergeben, werden abgedeckt.
#
# Chunk 83:
# Eine umfas­ sende Wesentlichkeitsanalyse erfolgt in einem gesonderten Prozess zur Vorberei­ tung auf die Berichterstattung 2024. Jedes Fokusthema ist – soweit aktuell bereits möglich – mit klaren Zielen und Meilensteinen sowie KPIs und Maßnahmen­ pak
#
# Chunk 84:
# Bereits heute sind ESG-relevante KPIs für die Mit­ glieder des Vorstands. Die als wesentlich eingestuften Themen bilden im Folgenden auch maßgeblich die Struktur dieses Nachhaltigkeitsbe­ richts.
#
# Chunk 85:
# Konzernstrategie NEW AUTO stellt neben technologischen und produktbezogenen Initiativen auch die Verbesserung der ESG-Performance des Unternehmens in den Fokus. Denn diese wirkt sich direkt und indirekt auf Marktkapitalisierung, Kapitalkosten und Attraktivität von Volkswagen für Investoren a
#
# Chunk 86:
# EU-Taxo­ nomie, CSRD oder Vorgaben zur verantwortungsbewussten Ausgestaltung von Lieferketten begründet. Zum anderen er­ warten Kapitalmarktakteure wie institutionelle Investoren.
#
# Chunk 87:
# Bereits heute ist ein wesentlicher Anteil des global verwalteten Vermögens an ESG-Kriterien orientiert. Wir schaffen zusätzliche Transparenz durch Offenlegung unserer Maßnahmen und Leistungskennzahlen.
#
# Chunk 88:
# Wir intensivieren unsere Kommunikation zu ESG und Nachhaltigkeit im Kapitalmarkt. Wir erläutern so unseren aktuellen Leistungsstand und profitieren zugleich von den Lerneffekten.
#
# Chunk 89:
# Nachhaltigkeitswirkungen neuer Mobilitätsangebote. Unter dem Titel ‘Impact Valuation @ Volkswagen Group’ ­erarbeiten wir aktuell ein konzernweites Konzept zur Impact- Bewertung.
#
# Chunk 90:
# Thema Impact-Bewertung voranzutreiben. Volkswagen Konzern gemeinsam mit der Marke Porsche Mitglied der ­Value Balancing Alliance. Initiative setzt sich auf internationaler Ebene branchenübergreifend.
#
# Chunk 91:
# Nachhaltigkeit bedeutet, langfristig tragfähige und intakte ökologische, soziale und übereinigte Systeme auf globaler, regionaler und lokaler Ebene zu erhalten. Value Balancing Alliance Inhalt includes 25 Struktur und Aufgaben.
#
# Chunk 92:
# Volkswagen hat vielfältig Einfluss auf diese Systeme. Die damit verbundenen Strukturen, Prozesse und Verantwortlichkeiten sind in einer spezifischen Konzernrichtlinie festgehalten.
#
# Chunk 93:
# Nachhaltigkeit ist Teil des TOP 10 Programms und wird über die strategische Steuerungsstruktur der Strategie NEW AUTO gelenkt. Die funktionsübergreifende Gesamtverantwortung trägt der Vorstandsvorsitzende der Volkswagen AG.
#
# Chunk 94:
# Konzernfunktion Nachhaltigkeit koordiniert. Dabei werden die Inhalte regelmäßig evaluiert und im Vorstand berichtet.
#
# Chunk 95:
# Kernpro­ zessen gehören: Nachhaltigkeitsstrategie, Stakeholder-Management, ESG-Ratings und -Rankings, Sustainability Policies. Sie dienen dazu, Transpa­ renz über externe Anforderungen zu schaffen und diese in unternehmerisches Handeln zu übersetzen.
#
# Chunk 96:
# Nachhaltigkeit ist dem Bereich Konzern- und Produktstrategie, Generalsekretariat zuge­ ordnet. Die Überarbeitung der Aufbau- und Ablauforganisation begonnen und wird vor­aussichtlich 2024 abgeschlossen.
#
# Chunk 97:
# Nachhaltigkeitsmanagement GRI 2-9, 2-12,2-13, 2 -14. Nachhals Sustainability Manager (Audi, Porsche ...) (CSO) Brand Sustainable Manager (CSM) (CMS) (CEO) CSO = Chief Sustainably Officer Steuerung funktions- übergreifender Themen Steuerunternehmens- spezifischer
#
# Chunk 98:
# Nachhaltigkeitsbeirat als unabhängiger Impulsgeber und Partner. Auf Konzernebene nimmt der Nachh altigkeitsthemen eine ­herausgehobene Stellung ein.
#
# Chunk 99:
# Das Gremium legt seine Arbeitsweise und -schwerpunkte unabhängig fest. Das Mandat des bisherigen Nachhaltigkeitsbeirats ist Ende 2022 ausgelaufen. Im Berichtszeitraum wurde mit seiner strategischen und personellen Neuausrichtung begonnen.
#
# Chunk 100:
# Die Volkswagen AG ist Teilnehmerin des UN Global Compact (UNGC) Die UNGC ist der weltweit größten Initiative für nachhaltige Unter­ nehmensführung.
#
# Chunk 101:
# Für die Transformation des Volkswagen Konzerns sind enorme Investitionen notwendig. Investoren auf der Suche nach nachhaltigen Anlagemöglichkeiten. Bereits seit 2020 verfügt die Volkswagen AG über ein Green Finance Framework.
#
# Chunk 102:
# "Wir verbinden unser Unternehmensziel der bi­ lanziellen CO2-Neutralität bis 2050 konsequent mit unserer Finanzierungsstrategie"
#
# Chunk 103:
# Green Finance Fra­ mework ist eine internationale Finanzbank für weltverträgliche Projekte. Die unter dem Green Finance Fra ­ mework aufgenommenen Mittel refinanzieren gezielt um­ welt Vertragsprojekt.
#
# Chunk 104:
# Volkswagen bietet innovative Fahrzeug­ technologien als auch zukunftsweisende Mobilitätsdienst­ leistungen. Will das Unternehmen den Wünschen seiner Kunden gerecht werden, aber also zur Lösung von lokalen Umwelt- und Verkehrsproblemen.
#
# Chunk 105:
# Uns leitet dabei die Vision ‘Mobility for gene­ rations to come’, die unsere Konzernstrategie NEW AUTO beschreibt. Wir gehen davon aus, dass die meisten Menschen bis 2030 weiterhin individuelle Mobilität bevorzugen.
#
# Chunk 106:
# Nachhaltigkeit von Mobilitätsangeboten mit Simulationen bewerten Vielfach zeigt sich. Es ist daher wichtig, eine Bewertungsbasis zu schaffen, damit Mobilitatetslösungen abgeschätzt und beeinflusst.
#
# Chunk 107:
# Die Fest­ legung der richtigen Rahmenbedingungen und Regulierungen ist von entscheidender Bedeutung, um substanzielle Beiträge für nachhaltige Städte zu leisten.
#
# Chunk 108:
# Mobilitätslösungen suchen wir den regelmäßigen Austausch mit Stakeholdern. Auch die Methoden und Modelle zur Mobilitätssimulation werden fortlaufend weiterentwickelt.
#
# Chunk 109:
# "Wir haben eine neue Methode entwickelt, die die die auf­ wändigen Rechenzeiten einer Simulation reduziert. Außerdem zielen wir darauf ab, unsere Ergebnis­ qualität durch den Abgleich mit Realdaten und Erfahrungs­ werten.
#
# Chunk 110:
# Kunden legen Wert auf kurze und verlässliche Reisezeiten, der Gesellschaft ist der Zugang für die Bürger sowie die Minderung der CO2-Emissionen wichtig.
#
# Chunk 111:
# Ein Erfolgsfaktor für die Wirksamkeit einer einzelnen Lösung ist ihre Einbindung in das Verkehrs- und Energiesystem. Beispielhaft zeigt dies ein E-Carsharing-Pilot­ projekt in Süddeutschland. Die AUDI AG als Partner beteiligt ist.
#
# Chunk 112:
# Das Projekt findet im ländlichen Raum statt, wo zumeist Privatfahrzeuge dominieren. Es zielt auch darauf ab, Mo­ bilitätslücken im ÖPNV-Angebot zu schließen.
#
# Chunk 113:
# Standort und Leis­ tungsstärke von öffentlichen Ladestellen sollten an den realen Wegen der E-Autofahrer orientiert sein. Dabei wurde der energiewirtschaftliche Themen­ schwerpunkt Ladeinfrastruktur zusammen mit dem Mobili­ tätsverhalten betrachtet.
#
# Chunk 114:
# 29 Gesellschaftliche Teilhabe verbessern. Soziale Aspekte spielen eine wichtige Rolle für Mobilitätslösungen. Hierzu gehört gerade im urbanen Raum ein attraktiver ÖPNV.
#
# Chunk 115:
# Stakeholder-Management verstehen die systema­ tische und kontinuierliche Interaktion mit wesentlichen Inte­ ressen- und Anspruchsgruppen der Gesellschaft. Fokusthemen ESG-Performance, Dekarbonisierung und Integrität, die Teil der Konzernstrategie NEW AUTO ist.
#
# Chunk 116:
# Unser Ziel ist ein offener, konstruktiver und auch kritischer Austausch mit den in der Grafik aufgeführten Stakeholdergruppen. Unsere Marken und Regionen verfügen über eigene Stakeholder-Managementstrategien. Aufgabe des Konzerns ist es, diese Aktivitäten in e
#
# Chunk 117:
# Das Stakeholder-Management gehört zu den Kernprozessen des Nachhaltigkeitsmanagements im Unternehmen. Dieser Rahmen umfasst die Beratung und Koordination der Marken und Regionen.
#
# Chunk 118:
# Aufgaben, Verantwortlichkeiten und Organisation sind in der Konzern­ richtlinie für Nachhaltigkeitsmanagement. Als international tätiges Unternehmen beeinflussen unsere Geschäftsaktivitäten das Leben vieler unterschiedlicher Menschen.
#
# Chunk 119:
# Ein entsprechend ausgerichtetes Stakeholder- Management ist unerlässlich, um die wesentlichen Hand­felder der Nachhaltigkeitsstrategie zu bestimmen. Dazu gehören die kontinuierliche Information und ein regelmäßiger Austausch mit allen Gesellschaftsbereichen.
#
# Chunk 120:
# Volkswagen ist ein weltweit führenden, softwareorientierten Mobilitätsanbieter. Er spielt auch eine wesentliche Rolle für die Erreichung der Unternehmensziele.
#
# Chunk 121:
# Auch hier ist es unser Anspruch, alle Stakeholder gleicher­ maßen zu berücksichtigen. Wir möchten sie zielgruppen­ gerecht informieren, aktiv in den Transformationsprozess einbinden.
#
# Chunk 122:
# Volkswagen ist Akteur in zahlreichen Netzwerken von Experten und Entscheidern. Unser Ziel ist, unser Unter­ nehmen unter den sich immer schneller und stärker verän­ dernden ökonomischen, ükologischen und gesellschaftlichen Rahmenbedingungen robust für die Zuk
#
# Chunk 123:
# Reputation-KPI misst Vertrauen der Stakeholder. Eine Übersicht der wichtigsten Mitgliedschaften findet sich online.
#
# Chunk 124:
# In Deutschland gaben 83 % der Stakeholder an, dass sie dem Volkswagen Konzern vertrauen (2022: 78%) Damit hat sich der Reputations-KPI im Vergleich zu 2022 deutlich verbessert.
#
# Chunk 125:
# Der Volkswagen Konzern hat zudem ein Stakeholder-Panel etabliert. Das gesamte Panel (DACH, EU) umfasst aktuell mehr als 200 Institutionen. 2023 wurde damit begonnen, einen syste­ matischen Analyseprozess für Stakeholders zu entwickeln.
#
# Chunk 126:
# "Wollen wir die Anre­ gungen und Empfehlungen ­unserer Stakeholder künftig noch besser aufnehmen" "Wissenschaftler" wollen die Möglichkeit für ­einen noch interaktiveren und transparenteren Austausch zu wichtigen unternehmensstrategischen.
#
# Chunk 127:
# Dekarbonisierung und Kreislaufwirtschaft are Fokusthemen. Gleichzeitig gehört die Umweltverträglichkeit unserer Produkte, Dienstleistungen und Prozesse.
#
# Chunk 128:
# Compliance mit Umweltregulierungen, Standards und freiwilligen Selbstverpflichtungen ist eine Grundvoraus­ setzung für unser Handeln. Das Konzernleitbild vereint dazu alle strategischen und compliancebezogenen ­Aspekte der Um­ weltaktivitäten.
#
# Chunk 129:
# KLIMA bekennen uns zum Pariser Klimaschutzabkommen. Wir streben ein 1,5-Grad-Ambitions­ niveau an. Das Leitbild legt den Fokus auf die vier in der folgenden Abbildung.
#
# Chunk 130:
# Bis spätestens 2050 wollen wir ein bilanziell CO₂-neutrales Unternehmen sein. Wir reduzieren schädliche Emissionen in Luft, Böden und Gewässer.
#
# Chunk 131:
# In der Umweltpolitik verpflichtet sich das Unternehmen, die ökologischen Auswirkungen unserer Prozesse, Produkte und Dienstleistungen zu verringern. Unsere Mitarbeiter schulen wir regelmäßig hinsichtlich Um­ weltschutz und Umw Earth-Compliance.
#
# Chunk 132:
# Die Richtlinie definiert die ­Mindestanforderungen an die operativen Organisationen für die Umsetzung eines Umwelt-Compliance-Management­ systems. Grundsätzlich sind alle Produktions- und Entwicklungsstand­ orte im Konzern dazu verpflichtet, ihre umweltmanagement­ systeme nach ISO 14001 zert
#
# Chunk 133:
# Die konzernweite Steuerung des Umweltschutzes erfolgt durch den Konzernsteuerkreis Umwelt and Energie. Dies schließt die Umsetzung der Programme zur Ressourceneffizienz und die Kontrolle der Zielerreichung.
#
# Chunk 134:
# Organisatorisch sind die Marken und Gesellschaften im ­Umweltbereich eigenständig verantwortlich. Sie leiten ihre Umweltschutzaktivitäten aus den konzernweit geltenden Zielen, Leitlinien and Grundsätzen ab. Zum Nachweis der Zielerreichung wer
#
# Chunk 135:
# Wir wollen das Management von chemischen Substanzen weiter verbessern. Wir verpflichten uns nach­ drücklich zur Einhaltung bestehender Vorschriften.
#
# Chunk 136:
# Dies umfasst den Herstellungsprozess mit Rohstoffentnahme, Werkstoffherstifferantenprozessen sowie eigener Produktion an unseren Standorten. Die Nutzungsphase mit den Fahrzeugemissionen und der notwendigen Ladestrom- und Kraftstoffbereitstellerung.
#
# Chunk 137:
# Bis 2025 sollen die pro­ duktionsbedingten Umweltbelastungen an allen Standorten zur Fertigung von Pkw und leichten Nutzfahrzeugen im Ver­ gleich zu 2010 um 45% reduziert werden.
#
# Chunk 138:
# Energiebedarf pro Fahrzeug: –21,0 % (2022: –14,2 %) CO2-Emissionen: –51,0%. Wasserverbrauch: –24,7%. Abfall zur Beseitigung: –75,9%. VOC-Emissions: –68,7% (20 22: –66,0%)
#
# Chunk 139:
# Volkswagen ist eine Fabrik ohne negative Auswirkungen auf die Umwelt. Mit der Funktionalbereichsstrategie one.PRODUCTION planen wir die Produktion von morgen. Ressourceneinsatz und Emissionen der Standorte des Volkswagen Konzerns ­erfordern dabei besondere Aufmerksamkeit.
#
# Chunk 140:
# Seit 2022 wenden die Marken die dafür entwickelten Messmethoden und Steuerungsinstrumente an. Diese ermöglichen uns das Erfassen und Reduzieren der quantitativen Umweltauswir­ kungen.
#
# Chunk 141:
# Im Jahr 2023 wurde ein weiterer wichtiger Meilenstein er­ reicht. 22 quantitative Umweltindikatoren – zum Beispiel CO2-Emissionen, Frischwasserbedarf, ­Abwasserfrachten – gemessen.
#
# Chunk 142:
# 143 weitere Umweltkriterien über­ prüfen wir mit der sogenannten Site Checklist. Dadurch können die umweltwirkungen untereinander verglichen. Reduktionsmaßnahmen gezielt dort angewendet werden.
#
# Chunk 143:
# UMWELTENTLASTUNG PRODUKTION (UEP) 25 % 2010–2018 KLIMA- UND UMWELTSCHUTZ Strategische Reduzierung von Ressourcen und Emissionen 2010 2018 2022 2025 2050.
#
# Chunk 144:
# Wasser ist eine wertvolle Ressource, mit der wir möglichst schonend umgehen wollen. Bis 2050 streben wir einen ‘Zero Impact’-Status für all Stand­ orte zur Fertigung von Pkw und leichten Nutzfahrzeugen an.
#
# Chunk 145:
# 50,6 % (rund 15,6 Mio. m³) unseres gesamten Frischwasserbedarfs zur Fertigung von Pkw und leichten Nutzfahrzeugen liegen. Das sind Gebiete mit Wasser­ mangel, wie zum Beispiel an unseren Standorten in Mexiko.
#
# Chunk 146:
# Wir legen Wert darauf, regelmäßigen Austausch zu Umwelt­ themen zu ermöglichen. Auch im aktuellen Berichtsjahr haben wir hierfür in verschiedenen Standorten und Regionen eine sogenannte umweltwoche durchgeführt – in der Konzernlogistik
#
# Chunk 147:
# Volkswagen engagiert sich seit 2007 über Naturschutzprojekte für den Schutz und Erhalt der bio­ logischen Vielfalt. Als Gründungsmitglied der Initiative Bio­ diversity in Good Company e. V.
#
# Chunk 148:
# Wir haben entsprechende Handlungsfelder definiert, um im Rahmen unseres wirtschaftlichen Handelns unseren Beitrag zum Erreichen dieser Ziele zu leisten. Eine Dokumentation hierüber erfolgt alle zwei Jahre in unserem Fortschrittsbe­ richt zur Initiative.
#
# Chunk 149:
# Biodiversität vor Ort fördern Naturschutzprojekten weltweit. Lokale Maßnahmen umfassen das Anlegen von Blühwiesen, Bäumen und Sträuchern.
#
# Chunk 150:
# "Wir haben einen KPI Biodiversität und ein internes Bewertungstool entwickelt. Dieses berück­ sichtigt sowohl direkte Maßnahmen zur Erhöhung der Biodi­ versittet am Standort"
#
# Chunk 151:
# Volkswagen AG Anzahl 567 466 Standorte mit ISO-14001-Zertifizierung oder EMAS-Validierung. Mitarbeiterzahl an allen Produktions­ standorten konzernweit.
#
# Chunk 152:
# Die Kennzahlen enthalten unvollständige Daten der Standorte von MAN Truck & Bus SE. Volkswagen Konzern (spezifisch) in kg/Fzg 1,29 1,40 Pkw & leichte Nfz 1,69 1,77 2.
#
# Chunk 153:
# Risikomanagement- and Internes Kontrollsystem (RMS and IKS) definiert die wesentlichen Grundsätze und Elemente für unseren Konzern. Es ist Grundlage einer angemessenen und wirksamen Steuerung.
#
# Chunk 154:
# Volkswagen ist unmit­ telbar für die Bewertung von nichtfinanziellen Risiken. Diese könnten bei der Verfolgung von Zielen und der Umsetzung von Maßnahmen in den Fokusbereichen unserer Konzernstrategie auftreten.
#
# Chunk 155:
# Die organisatorische Ausgestaltung des RMS und IKS ­basiert auf dem international anerkannten ‘COSO Enterprise Risk Management’-Rahmenwerk.
#
# Chunk 156:
# Volkswagen Drei-Linien-Modell aufsichtsrat/Vorstand Management Interne Revision Verantwortung, Berichterstattung Ausrichtung, Kommunikation, Koordination, Zusammenarbeit Delegation, Leitung, Ressourcen.
#
# Chunk 157:
# Ereignisse, die ein Risiko begründen können, werden de­ zentral in den Geschäftsbereichen und in den Konzerngesell­ schaften identifiziert. Eintrittswahrschein­ lichkeit, finanziellen Schaden und Reputationsschaden sowie die potenzielle Gefährdung der Ein
#
# Chunk 158:
# Wesentliche Risiken werden anlassbezogen an die relevanten Gremien gemeldet. Die Ergebnisse des operativen Risiko­ managements fließen kontinuierlich in die Planungs- und Kontrollrechnungen ein.
#
# Chunk 159:
# GRC(Governance, Risk, Compliance)-Regelprozess wird bis 2025 sukzessive durch ein standardisiertes IKS ersetzt. IKS werden nunmehr standardisierte Kontrollziele für die wesent­ lichen Konzerngesellschaften zur Abdeckung von Prozess­ risiken vorgegeben.
#
# Chunk 160:
# Die Konzernrevision unterstützt den Vorstand dabei. Sie über­ prüft das Risikofrüherkennungssystem. Wesent­liche Kontrollen zur Abdeckung der Prozessrisiken werden getestet.
#
# Chunk 161:
# Das Risikomanagement des Volkswagen Konzerns wird kon­ tinuierlich weiterentwickelt. Risiken, die sich auf unsere Fokusbereiche beziehen, finden sowohl in der Methodik als in den Inhalten unseres RMS und IKS Berücksichtigung. Im standardisierten IKS werden sogenannte Master-Kont
#
# Chunk 162:
# Master-Kontroll­ kataloge werden jährlich auf Aktualität hin geprüft und bei Bedarf angepasst. Risiken und Anforderungen mit Bezug auf Produkt- oder Umwelt-Compliance werdes in verschiedenen Master-kontrollkatalogen.
#
# Chunk 163:
# Inhalte zum Fokusthema ‘Dekarbo­ nisierung’ beispielsweise im Master-Kontrollkatalog ‘Umwelt und Nachhaltigkeit’ berücksichtigt. ‘Die wesentlichen Um­ welt- und Nacht- und Risiko sind nicht/unzureichend identifiziert�
#
# Chunk 164:
# Beispiels­ weise sind Risiko-Cluster für Umweltrisiken, Emissionsrisiken und Compliance-Risiken. Zu den Risiken, die sich auf unser finanzielles Ergebnis aus­ wirken können, gehören auch allgemeine Umwetrisiken sowie R isiken des Klimawandels.
#
# Chunk 165:
# Risiken sind Risiken, die aus unterschiedlichen CO2- und Emissionsvor­ gaben. Wetterextreme, Stürme oder Überschwemmungen mit Auswirkungen auf Produktion, Infrastruktur und Lieferketten.
#
# Chunk 166:
# Im Geschäftsjahr 2023 wurden weiter­ hin Risiken mit Bezug zur Einhaltung der Regulierungen zu CO2-Flottenemissionen in einzelnen Marken und Märkten identifiziert.
#
# Chunk 167:
# Volkswagen bekennen uns zum Pariser Klimaschutzabkommen. Wir richten unsere eigenen Aktivitäten am 1,5-Grad-Ziel aus. Bis 2050 beabsichtigen wir, ein bilanziell CO2-neutrales Unternehmen.
#
# Chunk 168:
# Weitere Aus­ führungen zu den Auswirkungen, Zielen und Maßnahmen sind im Kapitel Dekarbonisierung zu finden. Darüber hinaus sind keine weiteren wesentlichen Risiken im Sinne des § 289c Abs. 3 Nr. 4 HGB identifiziert worden.
#
# Chunk 169:
# 45 Gesellschaftliche Verantwortung weltweit wahrnehmen. Inhalt ist: Unternehmens-DNA | Dekarbonisierung | Kreislaufwirtschaft | Menschen in der Transformation.
#
# Chunk 170:
# Aus der Volkswagen AG heraus haben wir im Jahr 2023 ins­ gesamt 27,69 Mio. € für gesellschaftliche sowie Kultur- und Bildungsprojekte gespendet.
#
# Chunk 171:
# Konzernweite Organisationseinheit koordiniert bei humanitären Krisen Hilfsprojekte. Ziel ist es, schnell, umfassend und markenübergreifend Hilfe zu leisten.
#
# Chunk 172:
# Zahlreiche Pro­ duktionsstandorte im globalen Netzwerk von Volkswagen engagieren sich entweder in Form von Spenden, Freiwilligen­ arbeit oder eigeninitiierten Projekten.
#
# Chunk 173:
# Volkswagen Group ist eine der weltweite führenden CO₂-neutralen ­Unternehmen. Seit Beginn der Industrialisierung ist die welweite Durch­ schnittstemperatur bereits um etwa 1,2 Grad Celsius ge­ stiegen – mit drastischen Folgen für Natur, Gesellschaft und Wirtschaft.
#
# Chunk 174:
# Volkswagen ist einer der weltweit größten Automobilhersteller be­ wusst. Auf ihn entfallen nach Berechnungen des Weltklimarats derzeit rund 23 % der globalen energiebedingten Treibhausgasemissionen.
#
# Chunk 175:
# Volkswagen bekennt sich zum Pariser Klimaab­ kommen, nach dem der globale Temperaturanstieg bis 2050 auf deutlich unter 2 Grad Celsius begrenzt werden soll. Bis zum Jahr 2050 will Volkswagen ein bilanziell CO2-neutra­ les Unternehmen sein.
#
# Chunk 176:
# Kompen­ sationsmaßnahmen setzen wir verstärkt darauf, regenerativ erzeugten Strom in die Nutzungsphase zu integrieren. Die gesamte Stromversorgung unserer Werke auf erneuerbare Energien umzustellen.
#
# Chunk 177:
# In der vergangenen Fünfjahresplanung waren es noch 56 %. In der Konzernstrategie NEW AUTO nimmt die Dekarboni­ sierung der Geschäftsaktivitäten eine Schlüssel­ rolle.
#
# Chunk 178:
# Volkswagen Konzern hat ein konzernweites Nachhaltig­ keitsmanagement etabliert. Diese schaffen einheitlichen Rahmen für die freiwillige und konsis­tente Berichterstattung klimabezogener Finanzrisiken.
#
# Chunk 179:
# Vorstands­ vorsitzende der Volkswagen AG ist der Chief Sustainability Officer. Die hiermit verbundenen Strukturen, Prozesse und Verantwortlichkeiten sind in einer spezifischen Konzernrichtlinie festgehalten.
#
# Chunk 180:
# Nachhaltigkeit ist Teil des TOP 10 Programms. Wird gesteuert über die strategische Steuerungsstruktur. Dabei werden die Inhalte regelmäßig evaluiert.
#
# Chunk 181:
# Produkt- und Portfolio­ themen werden über den Konzernsteuerkreis Flotten-­ Compliance (KSK FC) gesteuert. 49 mindestens zweimal jährlich übers Themen wie beispiels­ weise Treibhausgasemissionen informiert.
#
# Chunk 182:
# Konzernweite Steuerung des Umweltschutzes obliegt dem Chief Executive Officer (CEO) der Marke Volkswagen Pkw. Dieser informiert den Konzernvorstand regelmäßig über nachhaltigkeits-, um­ welt- und energierelevante Themen.
#
# Chunk 183:
# Bereichsleiter Konzern- und Produktstrategie, Generalsekretariat berichtet über das TOP 10 Programm an den Vorstandsvorsitzenden und infor­ miert. Die beschriebenen Positionen haben die Aufgabe, die. Nachhaltigkeits-, Umwelt- und CO2-Aktivitäten zu koordi­ n
#
# Chunk 184:
# Volkswagen ist das Dekarbonisierungsindex (DKI) operationalisiert die Klima­ schutzziele des Volkswagen Konzerns. So nutzen wir das Feedback aus regelmäßig stattfindenden Stakeholder-dialogen, um unsere Strategien und Ansatz zu überprüfen.
#
# Chunk 185:
# Volkswagen ist der DKI für die CO2-Emissionen über den gesamten Fahrzeug- Lebensweg für Pkw und leichte Nutzfahrzeuge produzie­ renden Marken in den Regionen EU27+3, China and USA. Volkswagen hat unter anderem die Vergü­ tung seiner Vorstandsmitglieder an die
#
# Chunk 186:
# Weitere In­ formationen zur Berücksichtigung ­wesentlicher Nachhaltig­ keitskriterien in der Vorstandsvergütung liefert der Vergü­ tungsbericht des Volkswagen Konzerns. Darüber hinaus ist ab 2023 mit Einführung eines ESG-Faktors im Jahresbonus auch die Z
#
# Chunk 187:
# Nachfolgende Analyse zeigt einen Auszug aus der internen Auswertung wesentlicher Risiken und Chancen. Die Einhaltung von Flotten- und Abgasgrenzwerten kann technisch herausfordernd sein.
#
# Chunk 188:
# Volkswagen führt mit seinen Marken eine eng abgestimmte Technologie- und Produktplanung durch. Volkswagen unterstützt eine ambitionierte Bepreisung von CO2.
#
# Chunk 189:
# Rechtsverfahren für Unternehmen resultieren. Forderungen nach umfangreicheren Klimaschutz­ leistungen oder unvollständigen Angaben.
#
# Chunk 190:
# Der Konzern begegnet dem Risiko einerseits durch die Zerti­ fizierung seiner selbst gesetzten Dekarbonisierungs­ ziele mittels unabhängiger und international anerkannter Organisationen.
#
# Chunk 191:
# Der Konzern begegnet diesem Risiko durch die erfahrungsbasierte und frühzeitige Identifika­ tion von Schwachstellen. Der Ziel, Fahrzeuganläufe konzernweit hin­ sichtlich Stückzahl, Qualität und Termingerechtigkeit zu sichern.
#
# Chunk 192:
# Fahrzeugsteuern, die CO2-Ausstoß basieren, können zu einer Verschie­ bung der Nachfrage zugunsten kleinerer Segmente und Motoren führen. Der Konzern begegnet ­diesem Risiko.
#
# Chunk 193:
# Die Elektrifizierung des Portfolios sowie die Antriebs- und Kraftstoffstrategie des Konzerns bilden dafür die Grundlage. Der Übergang zu einer emissionsarmen Wirtschafts­ weise führt dazu, dass Marktteilnehmer ihre Energiever­ sorgung auf nichtfossile Quell
#
# Chunk 194:
# Nachfrage­ überhänge für Strom aus nichtfossilen Quellen können zu höheren Marktpreisen führen. Mehr­ kosten für den Konzern entstehen und die Erreichung seiner Dekarbonisierungsziele kann gefährdet.
#
# Chunk 195:
# Konzern begegnet diesem Risiko mit der gezielten Förderung des Aufbaus zusätzlicher Erzeugungskapa­ zi­täten für Strom.
#
# Chunk 196:
# Kritische Medienberichte oder eine defensive Kommuni­ kation des Konzerns in Bezug auf seine CO2-Emissio­ nen. Reduktionsziele sowie Dekarbonisierungsstrategie könnten möglicherweise zu Reputationsschäden führen.
#
# Chunk 197:
# Konzern begegnet dem Risiko durch regelmäßige Kommunikation seiner CO2-Bilanz, Emissionsreduktionsziele und Elektrifizie­ rungs- und Dekarbonisierungsstrategie in Geschäfts- und Nachhaltigkeitsberichten. Darüber hinaus fördert der Konzern die Kred
#
# Chunk 198:
# Extremwetterereignisse Potenzielle Störungen der eigenen Betriebsfähigkeit oder der Versorgung mit betriebskritischen Inputfaktoren wie zum Beispiel Halbleitern oder Batteriesys­temen als Schlüsselkomponenten der Elektrifizierung. Diese können zu Produkt
#
# Chunk 199:
# Extrem­ wetterbedingten Risiken begegnet Konzern einerseits durch Business-Continuity-Manage­ ment. Allokationsstrategien zur Verteilung produktionskritischer Inputfaktoren auf GRI 201-2 Inhalt.
#
# Chunk 200:
# Konzern identifiziert und erschließt derartige Potenzi­ ale. Konzern erscheint eine systematische Erfassung und Bewertung von ­Reduktionsmaßnahmen.
#
# Chunk 201:
# Eine positive CO2-Performance und kapitalmarktkon­ forme Berichterstattung können sich positiv auf Rating- Ergebnisse  auswirken. Daher sind ESG-Kriterien integraler Bestand­ teil der Konzernstrategie NEW AUTO.
#
# Chunk 202:
# Volkswagen Konzern veröffentlicht dritten Green Finance Report. "Green Finance Framework verbinden wir unser Unter­ nehmensziel der CO2-Neutralität bis 2050"
#
# Chunk 203:
# Szenarioanalyse als Entscheidungsgrundlage für Klimaschutz Volkswagen verwendet in verschiedenen Zusammenhängen Modelldaten und -annahmen.
#
# Chunk 204:
# IEA ist Mitglied in der Arbeitsgruppe des Mobility Model (MoMo) der International Energy Agency (IEA) Nutzen wir beispielsweise sogenannte IEA-ETP-Szenarien (‘Energy Technology Perspectives’) Darunter das ‘2°C Scenario’ (2DS) GRI 201-1 Inhalt ist eine Inh
#
# Chunk 205:
# Szenarioanalyse legt ihren Fokus auf die Berei­ che Produktion, Vertrieb und Technologie. Sie zeigt: Um die UN-Klimaziele zu erreichen, ist eine deutliche Verringerung der Emissionsintensität pro Fahrzeug notwendig.
#
# Chunk 206:
# Konzernstrategie NEW AUTO bekräftigte Entscheidung. Ent­ schieden in die Elektromobilität sowie in die Effizienzstei­ gerung.
#
# Chunk 207:
# Dekarbonisierungsprogramm nimmt gesamten Lebenszyklus in den Blick. An erster Stelle stehen Maßnahmen, mit denen sich CO2-Emissionen vermeiden.
#
# Chunk 208:
# Konzern ist auf regenerative Energieversorgung in allen Lebensphasen eines Fahrzeugs sukzessive. Zu­ letzt werden in ausgewählten Fällen nicht vermeidbare CO2-Emissionen über Klimaschutzprojekte kompensiert.
#
# Chunk 209:
# Wir möchten emissionsbedingte Risiken weitestgehend in strategische Entscheidungsprozesse integrieren. Zu diesem Zweck arbeiten wir im Rahmen der Portfoliosteuerung mit Schattenpreisen sowie mit einem internen Emissionshandel.
#
# Chunk 210:
# Dekarbonisierungsprogramm bewerten wir die Effizienz von Reduktionsmaßnahmen mithilfe von Vermeidungskosten. Wert wird auf Basis der Ziel­erreichung jährlich über­ prüft.
#
# Chunk 211:
# Wertschöpfungskette Kompensation der nicht vermeidbaren Emissionen, z. B. durch Investition in Wiederaufforstung. Inhalt ist Dekarbonisierung, Kreislaufwirtschaft, Vielfalt, Integrität und Compliance.
#
# Chunk 212:
#  Elektro­ fahrzeuge im europäischen Durchschnitt schon heute in der CO2-Bilanz in den meisten Märkten besser ab als vergleich­ bare Benzin- oder DieselfahrZEuge. Sie verursachen während der Nutzung keine lokalen Emissionen.
#
# Chunk 213:
# E-Antriebs-Baukasten (MEB) dient uns dabei als technisches Rückgrat der E-Offensive. Die neuen Elektroautos werden an 18 Standorten in Europa, China and den USA ­gebaut.
#
# Chunk 214:
# In der zweiten Hälfte der Dekade wird die E-Offensive durch die Scalable Systems Platform (SSP) ergänzt. 2023 hatten weitere E-Modelle verschiedener Marken ihren Markteintritt.
#
# Chunk 215:
# Kompaktwagens ID.3 bilanziell CO2-neutral. Fahrzeug­ innenraum des IDs.3 fortan ohne tierische Materialien aus.
#
# Chunk 216:
# Energiemix E-Strategie Effizienter Förderung eines kohlenstoffarmen Einzelhandelsnetzwerks Recycling and 2nd-Life Mobilitätslösungen. Energieeffizienz Versorgung mit erneuerbaren Energien Ökostrom für Kunden.
#
# Chunk 217:
# Rund 75 % der CO2-Emissionen eines Automobils entstehen im Gebrauch. E-Fahrzeuge spielen 100 % Strom aus erneuerbaren Quellen.
#
# Chunk 218:
# Volkswagen unterstützt Aufbau von Wind- und Solarparks. Einspei­ sung von Strom aus 100 % erneuerbaren Quellen verteilt über Europa.
#
# Chunk 219:
# Dekarbonisierung des Volkswagen Konzerns nimmt ihren Anfang in unseren Lieferketten. Damit können die Emissionen aus der Nutzungsphase unserer Elektrofahrzeug­ flotte bilanziell reduziert.
#
# Chunk 220:
# Ein Drittel der CO2-Emis­ sionen, die bei der Fertigung eines Elektroautos entstehen, aus der Herstellung von Hochvolt-Batteriezellen. Dabei sind die aufwendige Rohstoffgewinnung sowie die energieintensiven Prozesse bei the Batteriehersteller we­ sentliche Treiber
#
# Chunk 221:
# Alle Lieferanten (Neuvergaben) von HV-Batterien werden bereits heute vertraglich dazu verpflichtet, zertifizierten Strom aus erneuerbaren Quellen in ihrer Produktion einzusetzen.
#
# Chunk 222:
# Weitere Informationen zu Dekarbonisierungsmaßnahmen in vorgelagerten Wert­ schöpfungsstufen sind im Kapitel Lieferkette und Menschen­ rechte verankert. Volkswagen macht die CO2-Emissionen in Zukunft zu einem technischen Merk­ mal für relevante Bauteile.
#
# Chunk 223:
# Lieferanten müssen Maßnahmen in ihren eigenen Produktionsprozessen und Vor­ lieferketten umsetzen. Ein Beispiel ist die neue Mechatronik-Plattform SSP. So sind die Batterien der SSP-plattform mit einem CO2-Grenzwert versehen.
#
# Chunk 224:
# Volkswagen Pkw setzt weitere nachhaltige Bauteile ein. Batteriegehäuse und Felgen aus CO2-reduziertem Aluminium.
#
# Chunk 225:
# Die Zulieferer ­eine Erklärung unterschrieben, mit der sie sich zur Umstellung auf Strom aus erneuerbaren Energien verpflichten. So ent­ wickelt die Gruppe zusammen mit Lieferanten und Partnern einen Fahrplan.
#
# Chunk 226:
# Kathodenmaterialien sind der wichtigste technische Hebel für die Batterieleistung. Verantwortliche Rohstoffbeschaffung ist auch Basis des Joint Ventures IONWAY.
#
# Chunk 227:
# ...
#
# Chunk 341:
# Anforderungen im Produktbereich für Pkw und leichte Nutzfahrzeuge werden durch die Umsetzung der gesetzlichen End-of-Life-Vehicle-Anf orderungen in Verbindung mit der Typprüfung der Fahrzeugmodelle berücksichtigt. Darüber hin­ aus hat jede Marke Zie
#
# Chunk 342:
# Automobilsektor bereits stark reguliert, erkennbar an der öffentlich zugänglichen Global Automotive Declarable Substance List. Um als ökologisch nachhaltig zu gelten, darf eine Wirtschafts­ tätigkeit nicht zu einem erheblichen Anstieg der Schadstoffemissionen in Luft,
#
# Chunk 343:
# Gesellschaften erhielten risikospezifische Maßnahmen, die sie verpflichtend umsetzen mussten. Der Umsetzungsstand der Maß­ nahmen wird von Konzernseite laufend überwacht.
#
# Chunk 344:
# Wir legen unter anderem den Code of Conduct für Geschäfts­ partner zugrunde. Das Einhalten der darin definierten ver­ traglich verbindlichen Anforderungen wird von uns mithilfe eines Nachhaltigkeitsratings bei relevanten Lieferanten über­ prüft.
#
# Chunk 345:
# Auch in der vorgelagerten Lieferkette reagieren wir mit der systematischen Definition und Zuordnung von Maßnahme­ paketen, um die erkannten Verstöße abzustellen.
#
# Chunk 346:
# In 2022 haben wir ein Human-Rights-Focus-­ System implementiert. Das System hat zum Ziel, besonders hohe Risiken in unserer Lieferkette im Zusammenhang mit Menschenrechtsverletzungen sowie Umwelt zu erkennen.
#
# Chunk 347:
# Verteilungsschlüssel auf Basis der geplanten Fahrzeugvolumina angewendet. Diese Daten und Planungen sind Teil der finanziellen Mittelfristplanung.
#
# Chunk 348:
# Auf die Wirtschaftstätigkeit 3.3 “Herstellung von CO2-armen Verkehrstechnologien’ entfielen davon 294,0 Mrd. € bezie­ hungsweise 91,2 % vom Konzernumsatz.
#
# Chunk 349:
# Umsatzerlöse in Höhe von 165 Mio. € beziehungsweise 0,1 % vom Konzernumsatz. Hierin enthalten ist der Verkauf von Moto­ ren und Aggregaten für vollelektrische Fahrzeuge an Dritte.
#
# Chunk 350:
# Im Jahr 2023 waren dies 799 Tsd. Fahrzeuge und damit rund ein Drittel mehr als im Vorjahr. Ihr Anteil am relevanten Absatz – ohne die Fahr­ zeuge der chinesischen Joint Ventures – stieg auf 12,7 (11,1%)
#
# Chunk 351:
# Umsatzerlöse der Wirtschaftstätigkeit 3.18 ‘Herstellung von Automobil- und Mobilitätskomponenten’ hielten die Bewertungskriterien ein. Unter Berücksichtigung der DNSH-Kriterien und des Min­ destschutzes erfüllten im fahrzeugbezogenen Geschä
#
# Chunk 352:
# Wirt­ schaftstätigkeit 3.6 “Herstellung anderer CO2-armer Tech­ nologien’ zuzuordnen (3,1 Mrd. €), von denen 68 Mio. € taxo­ nomiekonform sind.
#
# Chunk 353:
# Umsatzerlöse 2023 ist ein Beitrag zum Klimaschutz. Einhaltung DNSH- Kriterien ist die  Mindest­ schutz. Taxonomiekonforme aret die bestehende Liste von Klima- und Substanzieller.
#
# Chunk 354:
# Die taxonomiefähigen Investitionsausgaben des fahrzeugbezogenen Geschäfts lagen bei 61,1 Mrd. €. Somit ergaben sich insgesamt gemäß EU-Taxonomie zu be­ rücksichtigende Investitions Ausgabens in Höhe von 61,5 Mrd €.
#
# Chunk 355:
# Fahrzeugmodells und der An­ triebstechnologie erhoben. Investitionsausgaben wurden, soweit möglich, unmittelbar Fahrzeugen zugeordnet. Sofern diese einen substanziellen Beitrag zum Umweltziel Klimaschutz leisten.
#
# Chunk 356:
# Investitionen an Standorten, die nur Fahrzeuge fertigen, die den Bewertungskriterien nicht ent­ sprechen, über den Verteilungsschlüssel nicht berücksichtigt. Das bedeutet, dass Investitionen in die Mittelfristplanung innerhalb der nächsten fünf Jahre ausschließlich Fah
#
# Chunk 357:
# Investitionsausgaben in Höhe von 20,0 (16,9) Mrd. €, das sind 32,6 (34,5) % der ge­ samten InvestitionsausGaben des Konzerns. Davon entfielen 5,9 Mrd., € auf immaterielle Vermögenswerte, 6,3 Mrd,. € auch Sachanlagen.
#
# Chunk 358:
# Taxonomiefähigen Investitionsausgaben im Bereich Power Engineering sind zum einen mit 37 Mio. € der Wirtschafts­ tätig­keit 3.2 “Herstellung von Anlagen für die Erzeugung und Verwendung von Wasserstoff’. Für Letztgenannte wurde eine Schlüsselung auf Gru
#
# Chunk 359:
# 24 Mio. € der Investitions­ ausgaben als taxonomiekonform ausgewiesen werden, die zu mehr als 90 % auf Sachanlagen entfielen.
#
# Chunk 360:
# Beitrag zum Klimaschutz Einhaltung DNSH- Kriterien. Mindest­ schutz Taxonomiekonforme Investitions­ ausgaben.
#
# Chunk 361:
# Wirtschafts­ tätigkeit 3.3 ‘Herstellung von CO2-armen Verkehrstechnolo­ gien’ klassifizieren wir als taxonomiefähig. Alle dem fahrzeugbezogenen Geschäft zuzurechnenden Be­ triebsausgaben stehen in Zusammenhang mit der Wirtscha
#
# Chunk 362:
# Nicht aktivierte Forschungs- und Entwicklungskosten wurden, soweit möglich, unmittelbar Fahrzeugen zugeordnet. Sofern diese einen substanziellen Beitrag zum Umweltziel Klimaschutz leisten, wurden sie berücksichtigt.
#
# Chunk 363:
# Der absolute Anstieg der taxonomiekonformen Betriebsausgaben ist auf die zunehmende Anzahl ökologisch nachhaltiger Fahrzeug­ projekte im Sinne der EU-Taxonomie.
#
# Chunk 364:
# Für Letztgenannte wurde für nicht direkt zuordenbare Betriebsausgaben eine Schlüsselung auf Grundlage des geplanten Umsatzes.
#
# Chunk 365:
# Taxonomiekonforme Betriebsausgaben für die ‘Herstellung von Anlagen f for die Erzeugung und Verwendung of Wasserstoff’ konnten in Höhe von 9 (4) Mio. € ausgewiesen werden. knapp zwei Drittel auf nicht aktivierte Forschungs- und Entwickl
#
# Chunk 366:
# Der CapEx-Plan im Sinne der EU-Taxonomie betrifft für das fahrzeugbezogene Geschäft die Wirtschaftstätigkeit 3.3 ‘Herstellung von CO2-armen Verkehrstechnologien’ des Umweltziels Klimaschutz. Zugänge aus vermieteten Vermög
#
# Chunk 367:
# Der CapEx-Plan im Sinne der EU-Taxonomie betrifft im Bereich Power Engineering die Wirtschaftstätigkeit 3.2 ‘Herstellung von Anlagen für die Erzeugung und Verwendung von Wasser­ stoff’
#
# Chunk 368:
# Der gesamte Kapitalaufwand die­ ses CapEx-Plans im Sinne der EU-Taxonomie, der im Be­ richtszeitraum und während der Mittelfrist­planung voraus­ sichtlich anfallen wird, beläuft sich auf rund 455 (300) Mio. €.
#
# Chunk 369:
# 80 Kriterien für einen wesentlichen Beitrag DNSH-Kriterien (‘keine erhebliche Beeinträchtigung’) Code Umsatz Umsatanteil 2023 Klimaschutz Anpassung an den Klimawandel Wasser Umwelt­ verschmutzung Kreislauf- wirtschaft Biologische Vielfalt Mindestschutz
#
# Chunk 370:
# Umsatz nicht taxonomiefähiger ­Tätigkeiten (B) 24.925 7,7 Gesamt (A + B) 322.284 100,0 1 Sämtliche Prozentangaben beziehen sich auf die gesamten Umsatzerlöse des Konzerns.
#
# Chunk 371:
# Ziel ist für das jeweilige Ziel taxonomiefähige Tätigkeit. N/EL: Für jeweils Ziel nicht taxonomiciefährige TÜTIGKEit.
#
# Chunk 372:
# 81 Kriterien für einen wesentlichen Beitrag DNSH-Kriterien (‘keine erhebliche Beeinträchtigung’) Code CapEx CapEx-Anteil 2023 Klimaschutz Anpassung an den Klimawandel Wasser Umwelt­ verschmutzung Kreislauf- wirtschaft Biologische Vielfalt Mindestschutz
#
# Chunk 373:
# CapEx nicht ­taxonomiefähiger ­Tätigkeiten (B) 221 0,4 Gesamt (A + B) 61.472 100,0 1 Sämtliche Prozentangaben beziehen sich auf die gesamten Investitionsausgaben.
#
# Chunk 374:
# Ziel ist für das jeweilige Ziel taxonomiefähige Tätigkeit. N/EL: Für jeweils Ziel nicht taxonomiciefährige TÜTIGKEit.
#
# Chunk 375:
# 82 Kriterien für einen wesentlichen Beitrag DNSH-Kriterien (‘keine erhebliche Beeinträchtigung’) Code OpEx OpEx-Anteil 2023 Klimaschutz Anpassung an den Klimawandel Wasser Umwelt­ verschmutzung Kreislauf- wirtschaft Biologische Vielfalt.
#
# Chunk 376:
# Sämtliche Prozentangaben beziehen sich auf die gesamten Betriebsausgaben des Konzerns. OpEx nicht ­taxonomiefähiger ­Tätigkeiten (B) 145 1,1 Gesamt (A + B) 13.265 100,0 1
#
# Chunk 377:
# Ziel ist für das jeweilige Ziel taxonomiefähige Tätigkeit. N/EL: Für jeweils Ziel nicht taxonomiciefährige TÜTIGKEit.
#
# Chunk 378:
# Kreislaufführung von Materialien trägt dazu bei, die negativen Umweltauswirkungen des Ressourcenver­ brauchs zu reduzieren. Das macht sie für den Volkswagen Konzern zu einem zentralen Nachhaltigkeitsthema.
#
# Chunk 379:
# Weitere Vorgaben werden sich aus der neuen Altfahr­ zeuggesetzgebung ergeben. Die EU-Kommission im Berichtsjahr einen ersten Entwurf vorgelegt hat.
#
# Chunk 380:
# Konzernweite Arbeitsstrukturen und Steuerkreise Volkswagen hat die Relevanz des Themas erkannt. Kreislaufwirtschaft ist als Fokusthema innerhalb der Konzern­ initiative 6.
#
# Chunk 381:
# Volkswagen setzt sich das Ziel, seine Ressour­ ceneffizienz weiter zu verbessern. Die Vision dahinter ist eine Fabrik ohne negative Auswirkungen auf die Umwelt.
#
# Chunk 382:
# Wirtschaftsweise streben wir an, unseren Ressourcenverbrauch zu minimieren, der er­ weiterten Herstellerverantwortung nachzukommen. Mit Blick auf eine kreislauffähige Wirtschaftweise Streit auf Energieverbrauchs zu reduzieren.
#
# Chunk 383:
# Für erste Schritte im Bereich Kreislaufwirtschaft haben wir uns auf die Aspek­ te Batterien, Stahl, Aluminium und Kunststoffe konzentriert. Die daraus resultierenden Ergebnisse fließen in die Weiter­ entwicklung der Gesamtstrategie. In geopoli­ tisch schwierigen Zeiten ge
#
# Chunk 384:
# Vorgehensweise bei der Abfallbeseitigung in der Produktion zielt darauf ab, unsere Abfallmenge zu senken. Das gelingt uns insbe­ sondere, indem wir eigene Materialkreisläufe schließen.
#
# Chunk 385:
# Auditoren sorgen für ein gemeinsames Verständnis des Qualitätsanspruchs an Entsorgungsdienstleistungen. Ergänzt wird dies durch einen regelmäßigen Austausch unter den Auditoren.
#
# Chunk 386:
# Zu den wichtigsten Maßnahmen, die wir für die Umsetzung der Kreislaufwirtschaft-Strategie ergreifen wollen, zählen die weitere Präzisierung von Zielen und Indikatoren. Das gilt für Komponenten und Materialien wie Batterien, Stahl, Aluminium oder Kunststoffe.
#
# Chunk 387:
# Nachhaltigkeits­ standards gelten für die Lieferanten. Für uns ist ein möglichst hoher Anteil wiederverwerteter Mate­ rialien sehr wichtig. Weitere Informationen hierzu finden sich in Kapitel ‘Lieferkette und Menschenrechte’
#
# Chunk 388:
# Batterierohstoffe sind wertvoll und ihr Verbleiben im Kreislauf aus vielerlei Hinsicht wichtig. So sind Abbau und Nutzung dieser Rohstoffen mit Emissionen und anderen negativen Um­ weltauswirkungen verbunden. Batterie-Nutzung trägt die Mehrfachnutzung
#
# Chunk 389:
# Ziel ist die industriali­ sierte Rückgewinnung wertvoller Rohmaterialien wie Lithium, Nickel, Mangan und Kobalt. Außerdem entwickeln wir in diesem Rahmen verschiedene Konzepte zum Entladen.
#
# Chunk 390:
# In der Pilotanlage werden nur Batterien recycelt. Die Anlage ist zunächst darauf ausgelegt, im Pilotbetrieb bis zu 3.600 Batteriesysteme im Jahr zu recyceln.
#
# Chunk 391:
# Somit werden die Produktionsinstrumente bei Volkswagen wieder aufbereitet. Unsere Orientierung an hoher Qualität zielt auf eine hohe Langlebigkeit ­unserer Fahrzeuge in der Nutzungsphase.
#
# Chunk 392:
# Austausch­ programms ist die Rückführung von sogenannten Altteilen von teilnehmenden Importeuren und Landesgesellschaften. Altteile, die nicht unmittelbar aufbereitet werden können, wer­ den durch ein fabrikneues Teil ersetzt.
#
# Chunk 393:
# Eine Reduzierung des Primärenergie­ bedarfs sowie eine Senkung der Treibhausgasemissionen um rund 97 % gegenüber den Primärrohstoffen erreichen. Die Ökobilanz wurde durch den TÜV Nord gemäß ISO 14040 extern geprüft.
#
# Chunk 394:
# Primär-Edelmetall Sekundär - 88 ‘Sustainable Parts’ bei Audi. Primärenergiebedarf (Megajoule, MJ) 27.641 366,2 760 11,7 –97 % –97% 26.881 kg –354,5 MJ (98 kWh) 0 % 20 % 40 % 60 % 80 % 100 %
#
# Chunk 395:
# In Ingolstadt werden dafür gebrauchte Fahrzeuge zerlegt. Die hochwertigen Ersatzteile stellen eine CO2-arme und preisgünstige Alternative.
#
# Chunk 396:
# Durch die Wiederverwertung der Aluminium­ abfälle kann bei der Herstellung bis zu 95 % der Energie gegenüber der Verwendung von Primäraluminium eingespart werden. Auf diesem Weg vermeidet Audi CO2-Emissionen und reduziert auch die Menge an benötigten Primärrohstof
#
# Chunk 397:
# Mehr als 850.000 t CO₂ wurden seit 2017 durch den Aluminium-­Closed-Loop bilanziell eingespart. Auch die in der Produktion entstehenden Abfälle mit Wert­ stoffgehalt werden immer systematischer.
#
# Chunk 398:
# Volkswagen Group Components will 20 t Aluminiumspäne rückgeführt beziehungsweise eingeschmolzen werden. Energiebedarf um etwa 3.250 MWh pro Jahr, CO2-Ausstoß um über 1.400 t pro year.
#
# Chunk 399:
# Kunststoffabfall ist prozessbedingt bei der Herstellung von Benzin-Tanks. Damit kann das Werk pro Jahr 2.500 t CO2 und 2 Mio. € Materialkosten einsparen.
#
# Chunk 400:
# Volkswagen Konzern ist aktiv an öffentlich geförderten For­ schungsprojekten zu Recyclingtechnologien beteiligt. Diese Forschungs­ projekte finden in Zusammenarbeit mit Partnern, Universitäten und Forsch Jungseinrichtungen in ganz Deutsch­ land statt.
#
# Chunk 401:
# Forschungskonsortium ‘HVBatCycle’ ist vom Bundeswirtschaftsministerium für Wirtschaft und Klimaschutz (BMWK) geförderte. Dies bezieht sich beispiels­ weise auf die Demontage von Batterien or die mehrfache Kreislaufführung der Rohstoffe.
#
# Chunk 402:
# Das Kon­ sortium besteht aus der TANIOBIS Gmbh, J. Schmalz GmbH, ­Viscom AG sowie Forschern der RWTH Aachen University, TU Braunschweig. Ziel ist es, wertvolle Materialien auf diese Weise dauerhaft zurückzugewinnen.
#
# Chunk 403:
# OHLF unterteilt sich in vier Forschungsfelder: Design for Circular Economy, Prozesse für Reverse Production, zirkuläre Werkstoffkonzepte sowie Gesamtsystemanalysen und -gestaltung. Die Erfahrung zeigt, dass die Zusammen­ arbeit zwischen Industrie und Wissenschaft – unter
#
# Chunk 404:
# Automobilindustrie befindet sich mitten in einer weitrei­ chenden technologischen Transformation. Aluminium-Closed-Loop-Projekt seit 2017 in t CO₂ 854.005 633.881 GRI 306-2 Inhalt für eine neue Epoche nachhaltiger Mobilität.
#
# Chunk 405:
# Volkswagen Group People Strategy stellen wir die Weichen, um diesen Wandel arbeitnehmer- und sozialverträg­ zu gestalten. Verantwortung für alle Sozialthemen trägt der Konzernvorstand Personal. Innerhalb der Volkswagen AG hat er in diesem Zusammenhang direktes Weisungsrecht.
#
# Chunk 406:
# Wesentliche Steuerungsinstrumente sind in diesem Zusammenhang Chartas, die Arbeitnehmerbelange abdecken, Konzern- und Markenrichtlinien sowie betriebliche Regelungen auf der Gesellschaftsebene.
#
# Chunk 407:
# Volkswagen ist ein sozial verantwortlicher Arbeitgeber, der als Mitglied des UN Global Compact in seinem personalpoliti­ schen Handeln internationalen Rahmenwerken und Standards der Nachhaltigkeit.
#
# Chunk 408:
# Die Sozialcharta richtet sich an den Konven­ tionen der International Labour Organization (ILO) aus. Darin verpflichten wir uns zu dem rechtlich gültigen und zu garantierenden nationalen Lohn­ minimum für alle Beschäftigten.
#
# Chunk 409:
# Die Grundsätze der Sozial­ charta wurden als Teil der Nachhaltigkeitsanforde­ rungen in der Lieferkette sowie in den Volkswagen Code of Conduct für Geschäftspartner integriert.
#
# Chunk 410:
# Eine besondere Herausforde­ rung ergibt sich daher in Staaten, die nicht das ILO-Über­ einkommen. Unser Ziel ist es, das Spannungsfeld zwischen den unterschied­ lichen nationalen Rahmenbedingungen zu überbrücken.
#
# Chunk 411:
# Volkswagen hat ein eigenes webbasiertes Informationsangebot zur Verfügung gestellt. Unser Ziel bei Volkswagen ist eine erfolgreiche und sozial verantwortliche Transformation.
#
# Chunk 412:
# Digitalisierung und Elektrifizierung getriebene Transformation der Automobilindustrie hat maßgebliche Auswirkungen auf unsere Produktstrategie – und damit auf benötigte Qualifikationen. Wir wollen auch künftig mög­ lichst hochqual ifizierte Mitarbeiter in attraktiven, zukun
#
# Chunk 413:
# Mitarbeiter aus traditionellen Produktionsbereichen in den benötigten Aufgabenfeldern entlang unserer Konzernstrategie NEW AUTO zu qualifizieren. Ein wesentliches Bestreben unserer Personal­ strategie besteht deshalb darin.
#
# Chunk 414:
# Transformation im Personalbereich als Fokusthema der Konzernstrategie. “Menschen in der Transformation“ steht im Zentrum unserer aktuellen und zukünftigen Aktivi­ täten.
#
# Chunk 415:
# Volkswagen ist eine Konzern­ initiative ‘People & Transformation’ auf den Weg gebracht. Eine Schlüsselrolle spielt dabei die vom KonzERNvorstand 2021 verabschiedete Personalstrategie (Group People Strategy)

# %%
pip install torch==2.6.0
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==2.6.0 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2)
# ERROR: No matching distribution found for torch==2.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
print(torch.__version__)
# Out:
# 2.2.2

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline
from tqdm import tqdm
import pandas as pd

# 📌 Deutsches Zusammenfassungsmodell laden
model_name = "mrm8488/bert2bert_shared-german-finetuned-summarization"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
summarizer = pipeline("summarization", model=model, tokenizer=tokenizer)

# 🧠 Funktion zur Key-Fact-Kompression
def compress_keyfact(text, max_len=50):
    try:
        result = summarizer(text, max_length=max_len, min_length=20, do_sample=False)
        return result[0]['summary_text']
    except Exception as e:
        print(f"Fehler bei Chunk: {e}")
        return None

# 🎯 Deine bereits gefilterten Chunks
# Beispiel: filtered_chunks = ["Die renommierte Science Based Targets Initiative ...", ...]
keyfacts = []

print("🔍 Extrahiere Key-Facts ...")
for chunk in tqdm(filtered_chunks):
    if len(chunk.strip()) > 50:
        summary = compress_keyfact(chunk)
        if summary:
            keyfacts.append({"original": chunk, "keyfact": summary})

# 💾 Ergebnisse als CSV speichern
df = pd.DataFrame(keyfacts)
df.to_csv("keyfacts_extrahiert.csv", index=False, encoding="utf-8-sig")

print("✅ Key-Facts extrahiert und gespeichert in 'keyfacts_extrahiert.csv'")
# Out:
# The following encoder weights were not tied to the decoder ['bert/pooler']
# The following encoder weights were not tied to the decoder ['bert/pooler']
# The following encoder weights were not tied to the decoder ['bert/pooler']
# Device set to use cpu
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[7], line 9
#       7 tokenizer = AutoTokenizer.from_pretrained(model_name)
#       8 model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# ----> 9 summarizer = pipeline("summarization", model=model, tokenizer=tokenizer)
#      11 # 🧠 Funktion zur Key-Fact-Kompression
#      12 def compress_keyfact(text, max_len=50):
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/pipelines/__init__.py:1180, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1177 if processor is not None:
#    1178     kwargs["processor"] = processor
# -> 1180 return pipeline_class(model=model, framework=framework, task=task, **kwargs)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/pipelines/text2text_generation.py:80, in Text2TextGenerationPipeline.__init__(self, *args, **kwargs)
#      79 def __init__(self, *args, **kwargs):
# ---> 80     super().__init__(*args, **kwargs)
#      82     self.check_model_type(
#      83         TF_MODEL_FOR_SEQ_TO_SEQ_CAUSAL_LM_MAPPING_NAMES
#      84         if self.framework == "tf"
#      85         else MODEL_FOR_SEQ_TO_SEQ_CAUSAL_LM_MAPPING_NAMES
#      86     )
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/pipelines/base.py:1016, in Pipeline.__init__(self, model, tokenizer, feature_extractor, image_processor, processor, modelcard, framework, task, args_parser, device, torch_dtype, binary_output, **kwargs)
#    1009 # We shouldn't call `model.to()` for models loaded with accelerate as well as the case that model is already on device
#    1010 if (
#    1011     self.framework == "pt"
#    1012     and self.model.device != self.device
#    1013     and not (isinstance(self.device, int) and self.device < 0)
#    1014     and hf_device_map is None
#    1015 ):
# -> 1016     self.model.to(self.device)
#    1018 # If it's a generation pipeline and the model can generate:
#    1019 # 1 - create a local generation config. This is done to avoid side-effects on the model as we apply local
#    1020 # tweaks to the generation config.
#    1021 # 2 - load the assistant model if it is passed.
#    1022 if self._pipeline_calls_generate and self.model.can_generate():
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:3851, in PreTrainedModel.to(self, *args, **kwargs)
#    3846     if dtype_present_in_args:
#    3847         raise ValueError(
#    3848             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    3849             " `dtype` by passing the correct `torch_dtype` argument."
#    3850         )
# -> 3851 return super().to(*args, **kwargs)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1152, in Module.to(self, *args, **kwargs)
#    1148         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1149                     non_blocking, memory_format=convert_to_format)
#    1150     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1152 return self._apply(convert)
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:825, in Module._apply(self, fn, recurse)
#     821 # Tensors stored in modules are graph leaves, and we don't want to
#     822 # track autograd history of `param_applied`, so we have to use
#     823 # `with torch.no_grad():`
#     824 with torch.no_grad():
# --> 825     param_applied = fn(param)
#     826 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     827 if should_use_set_data:
#
# File ~/Documents/Master/4. Semester/B5.3_Unternehmenssoftware/Greenwashing_Detector/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1150, in Module.to.<locals>.convert(t)
#    1147 if convert_to_format is not None and t.dim() in (4, 5):
#    1148     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1149                 non_blocking, memory_format=convert_to_format)
# -> 1150 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# NotImplementedError: Cannot copy out of meta tensor; no data!

# %% [markdown]
# # BERTopic für Themenanalyse

# %%
from bertopic import BERTopic

topic_model = BERTopic(language="german", embedding_model=model)
topics, probs = topic_model.fit_transform(chunks)

# Anzeigen der wichtigsten Themen
topic_model.get_topic_info()
# Out:
#    Topic  Count                   Name  \
# 0      0   1057       0_und_der_die_in
# 1      1    117  1_und_in_der_vielfalt
#
#                                       Representation  \
# 0  [und, der, die, in, im, für, von, den, zu, vol...
# 1  [und, in, der, vielfalt, compliance, menschenr...
#
#                                  Representative_Docs
# 0  [www.volkswagen-group.com > Charta der ­Beruf...
#  Unternehmens-DNA | Dekarbonisierung |...
